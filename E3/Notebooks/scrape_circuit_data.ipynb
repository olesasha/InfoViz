# %% [markdown]
# ### This Notebook scrapes all tracks and saves the pos data into a parquet-file

# %%
import fastf1 as ff1
import numpy as np
import pandas as pd
from tqdm import tqdm
from fastf1.ergast import Ergast
ergast = Ergast()

# %%
data = ff1.get_event_schedule(2024)

# %% [markdown]
# Get all GPs from the years 2020 to 2024

# %%
all_gps = []
for year in range(2020,2025):
    temp_df = pd.DataFrame(ff1.get_event_schedule(year)[["RoundNumber", "EventName"]])
    temp_df["year"] = year
    all_gps.append(temp_df)


df_all_gps = pd.concat(all_gps)

# %%
remove = ['70th Anniversary Grand Prix', 'Sakhir Grand Prix']

df_all_gps = df_all_gps.loc[
    ~df_all_gps["EventName"].isin(remove) &
    ~((df_all_gps["EventName"] == "Austrian Grand Prix") & (df_all_gps["year"] == 2020)) &
    ~((df_all_gps["EventName"] == "Styrian Grand Prix") & (df_all_gps["year"] == 2021)) & 
    ~((~df_all_gps["EventName"].isin(["Bahrain Grand Prix", "Saudi Arabian Grand Prix", "Australian Grand Prix", 
                                   "Japanese Grand Prix", "Chinese Grand Prix",  "Miami Grand Prix",
                                   "Emilia Romagna Grand Prix", "Monaco Grand Prix"]) & (df_all_gps["year"] == 2024)))
]

# %% [markdown]
# Drop testing events

# %%
df_all_gps = df_all_gps.replace({0:None},regex=True)
df_all_gps = df_all_gps.dropna()

# %% [markdown]
# Scrape the track data for every track

# %%
# Hilfsfunktion um Positionen gleich richtig zu rotieren
def rotate(xy, *, angle):
    rot_mat = np.array(
        [[np.cos(angle), np.sin(angle)], [-np.sin(angle), np.cos(angle)]]
    )
    return np.matmul(xy, rot_mat)

# %%
df_all_gps
# Out:
#    RoundNumber                  EventName  year
# 3            2         Styrian Grand Prix  2020
# 4            3       Hungarian Grand Prix  2020
# 5            4         British Grand Prix  2020
# 7            6         Spanish Grand Prix  2020
# 8            7         Belgian Grand Prix  2020
# ..         ...                        ...   ...
# 4            4        Japanese Grand Prix  2024
# 5            5         Chinese Grand Prix  2024
# 6            6           Miami Grand Prix  2024
# 7            7  Emilia Romagna Grand Prix  2024
# 8            8          Monaco Grand Prix  2024
#
# [87 rows x 3 columns]

# %%
all_track_data = []
for _,gp_data in tqdm(df_all_gps.iterrows()):
    year = gp_data["year"]
    gp = gp_data["RoundNumber"]
    gp_name = gp_data["EventName"]

    session = ff1.get_session(year,gp,"Q")
    session.load()
    df_temp_pos_data = session.laps.pick_fastest().get_pos_data()
    
    # add the first row to end to make the lap complete
    temp_first_row = df_temp_pos_data.iloc[:1,:]
    df_temp_pos_data = pd.concat([df_temp_pos_data,temp_first_row])
    
    track = df_temp_pos_data.loc[:, ("X", "Y")].to_numpy()

    circuit_info = session.get_circuit_info()
    # Convert the rotation angle from degrees to radian.
    track_angle = circuit_info.rotation / 180 * np.pi

    # Rotate and plot the track map.
    rotated_track = rotate(track, angle=track_angle)
    
    df_temp_track_data = pd.DataFrame(rotated_track, columns=["x", "y"])
    
    df_temp_track_data["round_number"] = gp
    df_temp_track_data["year"] = year
    df_temp_track_data["gp_name"] = gp_name
    all_track_data.append(df_temp_track_data)

df_track_data = pd.concat(all_track_data)
# Out:
# 0it [00:00, ?it/s]core           INFO 	Loading data for Styrian Grand Prix - Qualifying [v3.3.7]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# Request for URL https://ergast.com/api/f1/2020/2/qualifying.json failed; using cached response
# Traceback (most recent call last):
#   File "/opt/homebrew/lib/python3.12/site-packages/requests_cache/session.py", line 285, in _resend
#     response = self._send_and_cache(request, actions, cached_response, **kwargs)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/homebrew/lib/python3.12/site-packages/requests_cache/session.py", line 253, in _send_and_cache
#     response = super().send(request, **kwargs)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/homebrew/lib/python3.12/site-packages/fastf1/req.py", line 125, in send
#     lim.limit()
#   File "/opt/homebrew/lib/python3.12/site-packages/fastf1/req.py", line 102, in limit
#     raise RateLimitExceededError(self._info)
# fastf1.req.RateLimitExceededError: ergast.com: 200 calls/h
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# /opt/homebrew/lib/python3.12/site-packages/fastf1/core.py:1600: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '<TimedeltaArray>
# ['0 days 01:00:39.414000']
# Length: 1, dtype: timedelta64[ns]' has dtype incompatible with datetime64[ns], please explicitly cast to a compatible dtype first.
#   result.loc[mask, 'LapStartTime'] = result.loc[mask, 'PitOutTime']
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['44', '33', '55', '77', '31', '4', '23', '10', '3', '5', '16', '63', '18', '26', '20', '7', '11', '6', '99', '8']
# 1it [00:01,  1.13s/it]core           INFO 	Loading data for Hungarian Grand Prix - Qualifying [v3.3.7]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# Request for URL https://ergast.com/api/f1/2020/3/qualifying.json failed; using cached response
# Traceback (most recent call last):
#   File "/opt/homebrew/lib/python3.12/site-packages/requests_cache/session.py", line 285, in _resend
#     response = self._send_and_cache(request, actions, cached_response, **kwargs)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/homebrew/lib/python3.12/site-packages/requests_cache/session.py", line 253, in _send_and_cache
#     response = super().send(request, **kwargs)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/homebrew/lib/python3.12/site-packages/fastf1/req.py", line 125, in send
#     lim.limit()
#   File "/opt/homebrew/lib/python3.12/site-packages/fastf1/req.py", line 102, in limit
#     raise RateLimitExceededError(self._info)
# fastf1.req.RateLimitExceededError: ergast.com: 200 calls/h
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['44', '77', '18', '11', '5', '16', '33', '4', '55', '10', '3', '63', '23', '31', '6', '20', '26', '8', '99', '7']
# 2it [00:02,  1.01it/s]core           INFO 	Loading data for British Grand Prix - Qualifying [v3.3.7]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# Request for URL https://ergast.com/api/f1/2020/4/qualifying.json failed; using cached response
# Traceback (most recent call last):
#   File "/opt/homebrew/lib/python3.12/site-packages/requests_cache/session.py", line 285, in _resend
#     response = self._send_and_cache(request, actions, cached_response, **kwargs)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/homebrew/lib/python3.12/site-packages/requests_cache/session.py", line 253, in _send_and_cache
#     response = super().send(request, **kwargs)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/homebrew/lib/python3.12/site-packages/fastf1/req.py", line 125, in send
#     lim.limit()
#   File "/opt/homebrew/lib/python3.12/site-packages/fastf1/req.py", line 102, in limit
#     raise RateLimitExceededError(self._info)
# fastf1.req.RateLimitExceededError: ergast.com: 200 calls/h
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['44', '77', '33', '16', '4', '18', '55', '3', '31', '5', '10', '23', '27', '26', '63', '20', '99', '7', '8', '6']
# 3it [00:02,  1.08it/s]core           INFO 	Loading data for Spanish Grand Prix - Qualifying [v3.3.7]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# Request for URL https://ergast.com/api/f1/2020/6/qualifying.json failed; using cached response
# Traceback (most recent call last):
#   File "/opt/homebrew/lib/python3.12/site-packages/requests_cache/session.py", line 285, in _resend
#     response = self._send_and_cache(request, actions, cached_response, **kwargs)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/homebrew/lib/python3.12/site-packages/requests_cache/session.py", line 253, in _send_and_cache
#     response = super().send(request, **kwargs)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/homebrew/lib/python3.12/site-packages/fastf1/req.py", line 125, in send
#     lim.limit()
#   File "/opt/homebrew/lib/python3.12/site-packages/fastf1/req.py", line 102, in limit
#     raise RateLimitExceededError(self._info)
# fastf1.req.RateLimitExceededError: ergast.com: 200 calls/h
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['44', '77', '33', '11', '18', '23', '55', '4', '16', '10', '5', '26', '3', '7', '31', '20', '8', '63', '6', '99']
# core        WARNING 	Failed to preserve data type for column 'X' while merging telemetry.
# core        WARNING 	Failed to preserve data type for column 'Y' while merging telemetry.
# core        WARNING 	Failed to preserve data type for column 'Z' while merging telemetry.
# 4it [00:03,  1.12it/s]core           INFO 	Loading data for Belgian Grand Prix - Qualifying [v3.3.7]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# Request for URL https://ergast.com/api/f1/2020/7/qualifying.json failed; using cached response
# Traceback (most recent call last):
#   File "/opt/homebrew/lib/python3.12/site-packages/requests_cache/session.py", line 285, in _resend
#     response = self._send_and_cache(request, actions, cached_response, **kwargs)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/homebrew/lib/python3.12/site-packages/requests_cache/session.py", line 253, in _send_and_cache
#     response = super().send(request, **kwargs)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/homebrew/lib/python3.12/site-packages/fastf1/req.py", line 125, in send
#     lim.limit()
#   File "/opt/homebrew/lib/python3.12/site-packages/fastf1/req.py", line 102, in limit
#     raise RateLimitExceededError(self._info)
# fastf1.req.RateLimitExceededError: ergast.com: 200 calls/h
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['44', '77', '33', '3', '23', '31', '55', '11', '18', '4', '26', '10', '16', '5', '63', '7', '8', '99', '6', '20']
# 5it [00:04,  1.12it/s]core           INFO 	Loading data for Italian Grand Prix - Qualifying [v3.3.7]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# Request for URL https://ergast.com/api/f1/2020/8/qualifying.json failed; using cached response
# Traceback (most recent call last):
#   File "/opt/homebrew/lib/python3.12/site-packages/requests_cache/session.py", line 285, in _resend
#     response = self._send_and_cache(request, actions, cached_response, **kwargs)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/homebrew/lib/python3.12/site-packages/requests_cache/session.py", line 253, in _send_and_cache
#     response = super().send(request, **kwargs)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/homebrew/lib/python3.12/site-packages/fastf1/req.py", line 125, in send
#     lim.limit()
#   File "/opt/homebrew/lib/python3.12/site-packages/fastf1/req.py", line 102, in limit
#     raise RateLimitExceededError(self._info)
# fastf1.req.RateLimitExceededError: ergast.com: 200 calls/h
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['44', '77', '55', '11', '33', '4', '3', '18', '23', '10', '26', '31', '16', '7', '20', '8', '5', '99', '63', '6']
# 6it [00:05,  1.17it/s]core           INFO 	Loading data for Tuscan Grand Prix - Qualifying [v3.3.7]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# Request for URL https://ergast.com/api/f1/2020/9/qualifying.json failed; using cached response
# Traceback (most recent call last):
#   File "/opt/homebrew/lib/python3.12/site-packages/requests_cache/session.py", line 285, in _resend
#     response = self._send_and_cache(request, actions, cached_response, **kwargs)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/homebrew/lib/python3.12/site-packages/requests_cache/session.py", line 253, in _send_and_cache
#     response = super().send(request, **kwargs)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/homebrew/lib/python3.12/site-packages/fastf1/req.py", line 125, in send
#     lim.limit()
#   File "/opt/homebrew/lib/python3.12/site-packages/fastf1/req.py", line 102, in limit
#     raise RateLimitExceededError(self._info)
# fastf1.req.RateLimitExceededError: ergast.com: 200 calls/h
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['44', '77', '33', '23', '16', '11', '18', '3', '55', '31', '4', '26', '7', '5', '8', '10', '99', '63', '6', '20']
# core        WARNING 	Failed to preserve data type for column 'X' while merging telemetry.
# core        WARNING 	Failed to preserve data type for column 'Y' while merging telemetry.
# core        WARNING 	Failed to preserve data type for column 'Z' while merging telemetry.
# 7it [00:06,  1.18it/s]core           INFO 	Loading data for Russian Grand Prix - Qualifying [v3.3.7]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# Request for URL https://ergast.com/api/f1/2020/10/qualifying.json failed; using cached response
# Traceback (most recent call last):
#   File "/opt/homebrew/lib/python3.12/site-packages/requests_cache/session.py", line 285, in _resend
#     response = self._send_and_cache(request, actions, cached_response, **kwargs)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/homebrew/lib/python3.12/site-packages/requests_cache/session.py", line 253, in _send_and_cache
#     response = super().send(request, **kwargs)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/homebrew/lib/python3.12/site-packages/fastf1/req.py", line 125, in send
#     lim.limit()
#   File "/opt/homebrew/lib/python3.12/site-packages/fastf1/req.py", line 102, in limit
#     raise RateLimitExceededError(self._info)
# fastf1.req.RateLimitExceededError: ergast.com: 200 calls/h
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['44', '33', '77', '11', '3', '55', '31', '4', '10', '23', '16', '26', '18', '63', '5', '8', '99', '20', '6', '7']
# 8it [00:07,  1.12it/s]core           INFO 	Loading data for Eifel Grand Prix - Qualifying [v3.3.7]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# Request for URL https://ergast.com/api/f1/2020/11/qualifying.json failed; using cached response
# Traceback (most recent call last):
#   File "/opt/homebrew/lib/python3.12/site-packages/requests_cache/session.py", line 285, in _resend
#     response = self._send_and_cache(request, actions, cached_response, **kwargs)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/homebrew/lib/python3.12/site-packages/requests_cache/session.py", line 253, in _send_and_cache
#     response = super().send(request, **kwargs)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/homebrew/lib/python3.12/site-packages/fastf1/req.py", line 125, in send
#     lim.limit()
#   File "/opt/homebrew/lib/python3.12/site-packages/fastf1/req.py", line 102, in limit
#     raise RateLimitExceededError(self._info)
# fastf1.req.RateLimitExceededError: ergast.com: 200 calls/h
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['77', '44', '33', '16', '23', '3', '31', '4', '11', '55', '5', '10', '26', '99', '20', '8', '63', '6', '7', '27']
# 9it [00:07,  1.19it/s]core           INFO 	Loading data for Portuguese Grand Prix - Qualifying [v3.3.7]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# Request for URL https://ergast.com/api/f1/2020/12/qualifying.json failed; using cached response
# Traceback (most recent call last):
#   File "/opt/homebrew/lib/python3.12/site-packages/requests_cache/session.py", line 285, in _resend
#     response = self._send_and_cache(request, actions, cached_response, **kwargs)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/homebrew/lib/python3.12/site-packages/requests_cache/session.py", line 253, in _send_and_cache
#     response = super().send(request, **kwargs)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/homebrew/lib/python3.12/site-packages/fastf1/req.py", line 125, in send
#     lim.limit()
#   File "/opt/homebrew/lib/python3.12/site-packages/fastf1/req.py", line 102, in limit
#     raise RateLimitExceededError(self._info)
# fastf1.req.RateLimitExceededError: ergast.com: 200 calls/h
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['44', '77', '33', '16', '11', '23', '55', '4', '10', '3', '31', '18', '26', '63', '5', '7', '99', '8', '20', '6']
# core        WARNING 	Failed to preserve data type for column 'X' while merging telemetry.
# core        WARNING 	Failed to preserve data type for column 'Y' while merging telemetry.
# core        WARNING 	Failed to preserve data type for column 'Z' while merging telemetry.
# 10it [00:09,  1.09it/s]core           INFO 	Loading data for Emilia Romagna Grand Prix - Qualifying [v3.3.7]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# Request for URL https://ergast.com/api/f1/2020/13/qualifying.json failed; using cached response
# Traceback (most recent call last):
#   File "/opt/homebrew/lib/python3.12/site-packages/requests_cache/session.py", line 285, in _resend
#     response = self._send_and_cache(request, actions, cached_response, **kwargs)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/homebrew/lib/python3.12/site-packages/requests_cache/session.py", line 253, in _send_and_cache
#     response = super().send(request, **kwargs)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/homebrew/lib/python3.12/site-packages/fastf1/req.py", line 125, in send
#     lim.limit()
#   File "/opt/homebrew/lib/python3.12/site-packages/fastf1/req.py", line 102, in limit
#     raise RateLimitExceededError(self._info)
# fastf1.req.RateLimitExceededError: ergast.com: 200 calls/h
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['77', '44', '33', '10', '3', '23', '16', '26', '4', '55', '11', '31', '63', '5', '18', '8', '20', '7', '6', '99']
# 11it [00:09,  1.18it/s]core           INFO 	Loading data for Turkish Grand Prix - Qualifying [v3.3.7]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# Request for URL https://ergast.com/api/f1/2020/14/qualifying.json failed; using cached response
# Traceback (most recent call last):
#   File "/opt/homebrew/lib/python3.12/site-packages/requests_cache/session.py", line 285, in _resend
#     response = self._send_and_cache(request, actions, cached_response, **kwargs)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/homebrew/lib/python3.12/site-packages/requests_cache/session.py", line 253, in _send_and_cache
#     response = super().send(request, **kwargs)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/homebrew/lib/python3.12/site-packages/fastf1/req.py", line 125, in send
#     lim.limit()
#   File "/opt/homebrew/lib/python3.12/site-packages/fastf1/req.py", line 102, in limit
#     raise RateLimitExceededError(self._info)
# fastf1.req.RateLimitExceededError: ergast.com: 200 calls/h
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['18', '33', '11', '23', '3', '44', '31', '7', '77', '99', '4', '5', '55', '16', '10', '20', '26', '63', '8', '6']
# 12it [00:10,  1.06it/s]core           INFO 	Loading data for Bahrain Grand Prix - Qualifying [v3.3.7]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# Request for URL https://ergast.com/api/f1/2020/15/qualifying.json failed; using cached response
# Traceback (most recent call last):
#   File "/opt/homebrew/lib/python3.12/site-packages/requests_cache/session.py", line 285, in _resend
#     response = self._send_and_cache(request, actions, cached_response, **kwargs)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/homebrew/lib/python3.12/site-packages/requests_cache/session.py", line 253, in _send_and_cache
#     response = super().send(request, **kwargs)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/homebrew/lib/python3.12/site-packages/fastf1/req.py", line 125, in send
#     lim.limit()
#   File "/opt/homebrew/lib/python3.12/site-packages/fastf1/req.py", line 102, in limit
#     raise RateLimitExceededError(self._info)
# fastf1.req.RateLimitExceededError: ergast.com: 200 calls/h
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['44', '77', '33', '23', '11', '3', '31', '10', '4', '26', '5', '16', '18', '63', '55', '99', '7', '20', '8', '6']
# 13it [00:11,  1.11it/s]core           INFO 	Loading data for Abu Dhabi Grand Prix - Qualifying [v3.3.7]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# Request for URL https://ergast.com/api/f1/2020/17/qualifying.json failed; using cached response
# Traceback (most recent call last):
#   File "/opt/homebrew/lib/python3.12/site-packages/requests_cache/session.py", line 285, in _resend
#     response = self._send_and_cache(request, actions, cached_response, **kwargs)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/homebrew/lib/python3.12/site-packages/requests_cache/session.py", line 253, in _send_and_cache
#     response = super().send(request, **kwargs)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/homebrew/lib/python3.12/site-packages/fastf1/req.py", line 125, in send
#     lim.limit()
#   File "/opt/homebrew/lib/python3.12/site-packages/fastf1/req.py", line 102, in limit
#     raise RateLimitExceededError(self._info)
# fastf1.req.RateLimitExceededError: ergast.com: 200 calls/h
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['33', '77', '44', '4', '23', '55', '26', '18', '16', '10', '31', '3', '5', '99', '11', '7', '20', '63', '51', '6']
# core        WARNING 	Failed to preserve data type for column 'X' while merging telemetry.
# core        WARNING 	Failed to preserve data type for column 'Y' while merging telemetry.
# core        WARNING 	Failed to preserve data type for column 'Z' while merging telemetry.
# 14it [00:12,  1.15it/s]core           INFO 	Loading data for Bahrain Grand Prix - Qualifying [v3.3.7]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# Request for URL https://ergast.com/api/f1/2021/1/qualifying.json failed; using cached response
# Traceback (most recent call last):
#   File "/opt/homebrew/lib/python3.12/site-packages/requests_cache/session.py", line 285, in _resend
#     response = self._send_and_cache(request, actions, cached_response, **kwargs)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/homebrew/lib/python3.12/site-packages/requests_cache/session.py", line 253, in _send_and_cache
#     response = super().send(request, **kwargs)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/homebrew/lib/python3.12/site-packages/fastf1/req.py", line 125, in send
#     lim.limit()
#   File "/opt/homebrew/lib/python3.12/site-packages/fastf1/req.py", line 102, in limit
#     raise RateLimitExceededError(self._info)
# fastf1.req.RateLimitExceededError: ergast.com: 200 calls/h
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['33', '44', '77', '16', '10', '3', '4', '55', '14', '18', '11', '99', '22', '7', '63', '31', '6', '5', '47', '9']
# core        WARNING 	Failed to preserve data type for column 'X' while merging telemetry.
# core        WARNING 	Failed to preserve data type for column 'Y' while merging telemetry.
# core        WARNING 	Failed to preserve data type for column 'Z' while merging telemetry.
# 15it [00:13,  1.19it/s]core           INFO 	Loading data for Emilia Romagna Grand Prix - Qualifying [v3.3.7]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# Request for URL https://ergast.com/api/f1/2021/2/qualifying.json failed; using cached response
# Traceback (most recent call last):
#   File "/opt/homebrew/lib/python3.12/site-packages/requests_cache/session.py", line 285, in _resend
#     response = self._send_and_cache(request, actions, cached_response, **kwargs)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/homebrew/lib/python3.12/site-packages/requests_cache/session.py", line 253, in _send_and_cache
#     response = super().send(request, **kwargs)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/homebrew/lib/python3.12/site-packages/fastf1/req.py", line 125, in send
#     lim.limit()
#   File "/opt/homebrew/lib/python3.12/site-packages/fastf1/req.py", line 102, in limit
#     raise RateLimitExceededError(self._info)
# fastf1.req.RateLimitExceededError: ergast.com: 200 calls/h
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['44', '11', '33', '16', '10', '3', '4', '77', '31', '18', '55', '63', '5', '6', '14', '7', '99', '47', '9', '22']
# core        WARNING 	Failed to preserve data type for column 'X' while merging telemetry.
# core        WARNING 	Failed to preserve data type for column 'Y' while merging telemetry.
# core        WARNING 	Failed to preserve data type for column 'Z' while merging telemetry.
# 16it [00:14,  1.19it/s]core           INFO 	Loading data for Portuguese Grand Prix - Qualifying [v3.3.7]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# Request for URL https://ergast.com/api/f1/2021/3/qualifying.json failed; using cached response
# Traceback (most recent call last):
#   File "/opt/homebrew/lib/python3.12/site-packages/requests_cache/session.py", line 285, in _resend
#     response = self._send_and_cache(request, actions, cached_response, **kwargs)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/homebrew/lib/python3.12/site-packages/requests_cache/session.py", line 253, in _send_and_cache
#     response = super().send(request, **kwargs)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/homebrew/lib/python3.12/site-packages/fastf1/req.py", line 125, in send
#     lim.limit()
#   File "/opt/homebrew/lib/python3.12/site-packages/fastf1/req.py", line 102, in limit
#     raise RateLimitExceededError(self._info)
# fastf1.req.RateLimitExceededError: ergast.com: 200 calls/h
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['77', '44', '33', '11', '55', '31', '4', '16', '10', '5', '63', '99', '14', '22', '7', '3', '18', '6', '47', '9']
# 17it [00:14,  1.22it/s]core           INFO 	Loading data for Spanish Grand Prix - Qualifying [v3.3.7]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# Request for URL https://ergast.com/api/f1/2021/4/qualifying.json failed; using cached response
# Traceback (most recent call last):
#   File "/opt/homebrew/lib/python3.12/site-packages/requests_cache/session.py", line 285, in _resend
#     response = self._send_and_cache(request, actions, cached_response, **kwargs)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/homebrew/lib/python3.12/site-packages/requests_cache/session.py", line 253, in _send_and_cache
#     response = super().send(request, **kwargs)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/homebrew/lib/python3.12/site-packages/fastf1/req.py", line 125, in send
#     lim.limit()
#   File "/opt/homebrew/lib/python3.12/site-packages/fastf1/req.py", line 102, in limit
#     raise RateLimitExceededError(self._info)
# fastf1.req.RateLimitExceededError: ergast.com: 200 calls/h
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['44', '33', '77', '16', '31', '55', '3', '11', '4', '14', '18', '10', '5', '99', '63', '22', '7', '47', '6', '9']
# 18it [00:15,  1.21it/s]core           INFO 	Loading data for Monaco Grand Prix - Qualifying [v3.3.7]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# Request for URL https://ergast.com/api/f1/2021/5/qualifying.json failed; using cached response
# Traceback (most recent call last):
#   File "/opt/homebrew/lib/python3.12/site-packages/requests_cache/session.py", line 285, in _resend
#     response = self._send_and_cache(request, actions, cached_response, **kwargs)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/homebrew/lib/python3.12/site-packages/requests_cache/session.py", line 253, in _send_and_cache
#     response = super().send(request, **kwargs)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/homebrew/lib/python3.12/site-packages/fastf1/req.py", line 125, in send
#     lim.limit()
#   File "/opt/homebrew/lib/python3.12/site-packages/fastf1/req.py", line 102, in limit
#     raise RateLimitExceededError(self._info)
# fastf1.req.RateLimitExceededError: ergast.com: 200 calls/h
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# core        WARNING 	No lap data for driver 47
# core        WARNING 	Driver  5: Lap timing integrity check failed for 1 lap(s)
# core        WARNING 	Failed to perform lap accuracy check - all laps marked as inaccurate (driver 47)
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['16', '33', '77', '55', '4', '10', '44', '5', '11', '99', '31', '3', '18', '7', '63', '22', '14', '6', '9', '47']
# core        WARNING 	Failed to preserve data type for column 'X' while merging telemetry.
# core        WARNING 	Failed to preserve data type for column 'Y' while merging telemetry.
# core        WARNING 	Failed to preserve data type for column 'Z' while merging telemetry.
# 19it [00:16,  1.22it/s]core           INFO 	Loading data for Azerbaijan Grand Prix - Qualifying [v3.3.7]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# Request for URL https://ergast.com/api/f1/2021/6/qualifying.json failed; using cached response
# Traceback (most recent call last):
#   File "/opt/homebrew/lib/python3.12/site-packages/requests_cache/session.py", line 285, in _resend
#     response = self._send_and_cache(request, actions, cached_response, **kwargs)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/homebrew/lib/python3.12/site-packages/requests_cache/session.py", line 253, in _send_and_cache
#     response = super().send(request, **kwargs)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/homebrew/lib/python3.12/site-packages/fastf1/req.py", line 125, in send
#     lim.limit()
#   File "/opt/homebrew/lib/python3.12/site-packages/fastf1/req.py", line 102, in limit
#     raise RateLimitExceededError(self._info)
# fastf1.req.RateLimitExceededError: ergast.com: 200 calls/h
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['16', '44', '33', '10', '55', '4', '11', '22', '14', '77', '5', '31', '3', '7', '63', '6', '47', '9', '18', '99']
# 20it [00:17,  1.15it/s]core           INFO 	Loading data for French Grand Prix - Qualifying [v3.3.7]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# Request for URL https://ergast.com/api/f1/2021/7/qualifying.json failed; using cached response
# Traceback (most recent call last):
#   File "/opt/homebrew/lib/python3.12/site-packages/requests_cache/session.py", line 285, in _resend
#     response = self._send_and_cache(request, actions, cached_response, **kwargs)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/homebrew/lib/python3.12/site-packages/requests_cache/session.py", line 253, in _send_and_cache
#     response = super().send(request, **kwargs)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/homebrew/lib/python3.12/site-packages/fastf1/req.py", line 125, in send
#     lim.limit()
#   File "/opt/homebrew/lib/python3.12/site-packages/fastf1/req.py", line 102, in limit
#     raise RateLimitExceededError(self._info)
# fastf1.req.RateLimitExceededError: ergast.com: 200 calls/h
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['33', '44', '77', '11', '55', '10', '16', '4', '14', '3', '31', '5', '99', '63', '47', '6', '7', '9', '18', '22']
# core        WARNING 	Failed to preserve data type for column 'X' while merging telemetry.
# core        WARNING 	Failed to preserve data type for column 'Y' while merging telemetry.
# core        WARNING 	Failed to preserve data type for column 'Z' while merging telemetry.
# 21it [00:18,  1.15it/s]core           INFO 	Loading data for Austrian Grand Prix - Qualifying [v3.3.7]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# Request for URL https://ergast.com/api/f1/2021/9/qualifying.json failed; using cached response
# Traceback (most recent call last):
#   File "/opt/homebrew/lib/python3.12/site-packages/requests_cache/session.py", line 285, in _resend
#     response = self._send_and_cache(request, actions, cached_response, **kwargs)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/homebrew/lib/python3.12/site-packages/requests_cache/session.py", line 253, in _send_and_cache
#     response = super().send(request, **kwargs)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/homebrew/lib/python3.12/site-packages/fastf1/req.py", line 125, in send
#     lim.limit()
#   File "/opt/homebrew/lib/python3.12/site-packages/fastf1/req.py", line 102, in limit
#     raise RateLimitExceededError(self._info)
# fastf1.req.RateLimitExceededError: ergast.com: 200 calls/h
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['33', '4', '11', '44', '77', '10', '22', '5', '63', '18', '55', '16', '3', '14', '99', '7', '31', '6', '47', '9']
# core        WARNING 	Failed to preserve data type for column 'X' while merging telemetry.
# core        WARNING 	Failed to preserve data type for column 'Y' while merging telemetry.
# core        WARNING 	Failed to preserve data type for column 'Z' while merging telemetry.
# 22it [00:19,  1.16it/s]core           INFO 	Loading data for British Grand Prix - Qualifying [v3.3.7]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# Request for URL https://ergast.com/api/f1/2021/10/qualifying.json failed; using cached response
# Traceback (most recent call last):
#   File "/opt/homebrew/lib/python3.12/site-packages/requests_cache/session.py", line 285, in _resend
#     response = self._send_and_cache(request, actions, cached_response, **kwargs)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/homebrew/lib/python3.12/site-packages/requests_cache/session.py", line 253, in _send_and_cache
#     response = super().send(request, **kwargs)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/homebrew/lib/python3.12/site-packages/fastf1/req.py", line 125, in send
#     lim.limit()
#   File "/opt/homebrew/lib/python3.12/site-packages/fastf1/req.py", line 102, in limit
#     raise RateLimitExceededError(self._info)
# fastf1.req.RateLimitExceededError: ergast.com: 200 calls/h
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['44', '33', '77', '16', '11', '4', '3', '63', '55', '5', '14', '10', '31', '99', '18', '22', '7', '6', '47', '9']
# core        WARNING 	Failed to preserve data type for column 'X' while merging telemetry.
# core        WARNING 	Failed to preserve data type for column 'Y' while merging telemetry.
# core        WARNING 	Failed to preserve data type for column 'Z' while merging telemetry.
# 23it [00:20,  1.17it/s]core           INFO 	Loading data for Hungarian Grand Prix - Qualifying [v3.3.7]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# Request for URL https://ergast.com/api/f1/2021/11/qualifying.json failed; using cached response
# Traceback (most recent call last):
#   File "/opt/homebrew/lib/python3.12/site-packages/requests_cache/session.py", line 285, in _resend
#     response = self._send_and_cache(request, actions, cached_response, **kwargs)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/homebrew/lib/python3.12/site-packages/requests_cache/session.py", line 253, in _send_and_cache
#     response = super().send(request, **kwargs)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/homebrew/lib/python3.12/site-packages/fastf1/req.py", line 125, in send
#     lim.limit()
#   File "/opt/homebrew/lib/python3.12/site-packages/fastf1/req.py", line 102, in limit
#     raise RateLimitExceededError(self._info)
# fastf1.req.RateLimitExceededError: ergast.com: 200 calls/h
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# core        WARNING 	No lap data for driver 47
# core        WARNING 	Failed to perform lap accuracy check - all laps marked as inaccurate (driver 47)
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['44', '77', '33', '11', '10', '4', '16', '31', '14', '5', '3', '18', '7', '99', '55', '22', '63', '6', '9', '47']
# 24it [00:20,  1.17it/s]core           INFO 	Loading data for Belgian Grand Prix - Qualifying [v3.3.7]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# Request for URL https://ergast.com/api/f1/2021/12/qualifying.json failed; using cached response
# Traceback (most recent call last):
#   File "/opt/homebrew/lib/python3.12/site-packages/requests_cache/session.py", line 285, in _resend
#     response = self._send_and_cache(request, actions, cached_response, **kwargs)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/homebrew/lib/python3.12/site-packages/requests_cache/session.py", line 253, in _send_and_cache
#     response = super().send(request, **kwargs)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/homebrew/lib/python3.12/site-packages/fastf1/req.py", line 125, in send
#     lim.limit()
#   File "/opt/homebrew/lib/python3.12/site-packages/fastf1/req.py", line 102, in limit
#     raise RateLimitExceededError(self._info)
# fastf1.req.RateLimitExceededError: ergast.com: 200 calls/h
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# ...
# Request for URL https://ergast.com/api/f1/2024/1/qualifying.json failed; using cached response
# Traceback (most recent call last):
#   File "/opt/homebrew/lib/python3.12/site-packages/requests_cache/session.py", line 285, in _resend
#     response = self._send_and_cache(request, actions, cached_response, **kwargs)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/homebrew/lib/python3.12/site-packages/requests_cache/session.py", line 253, in _send_and_cache
#     response = super().send(request, **kwargs)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/homebrew/lib/python3.12/site-packages/fastf1/req.py", line 125, in send
#     lim.limit()
#   File "/opt/homebrew/lib/python3.12/site-packages/fastf1/req.py", line 102, in limit
#     raise RateLimitExceededError(self._info)
# fastf1.req.RateLimitExceededError: ergast.com: 200 calls/h
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['1', '16', '63', '55', '11', '14', '4', '81', '44', '27', '22', '18', '23', '3', '20', '77', '24', '2', '31', '10']
# 80it [01:07,  1.31it/s]core           INFO 	Loading data for Saudi Arabian Grand Prix - Qualifying [v3.3.7]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# Request for URL https://ergast.com/api/f1/2024/2/qualifying.json failed; using cached response
# Traceback (most recent call last):
#   File "/opt/homebrew/lib/python3.12/site-packages/requests_cache/session.py", line 285, in _resend
#     response = self._send_and_cache(request, actions, cached_response, **kwargs)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/homebrew/lib/python3.12/site-packages/requests_cache/session.py", line 253, in _send_and_cache
#     response = super().send(request, **kwargs)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/homebrew/lib/python3.12/site-packages/fastf1/req.py", line 125, in send
#     lim.limit()
#   File "/opt/homebrew/lib/python3.12/site-packages/fastf1/req.py", line 102, in limit
#     raise RateLimitExceededError(self._info)
# fastf1.req.RateLimitExceededError: ergast.com: 200 calls/h
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['1', '16', '11', '14', '81', '4', '63', '44', '22', '18', '38', '23', '20', '3', '27', '77', '31', '10', '2', '24']
# core        WARNING 	Failed to preserve data type for column 'X' while merging telemetry.
# core        WARNING 	Failed to preserve data type for column 'Y' while merging telemetry.
# core        WARNING 	Failed to preserve data type for column 'Z' while merging telemetry.
# 81it [01:08,  1.29it/s]core           INFO 	Loading data for Australian Grand Prix - Qualifying [v3.3.7]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# Request for URL https://ergast.com/api/f1/2024/3/qualifying.json failed; using cached response
# Traceback (most recent call last):
#   File "/opt/homebrew/lib/python3.12/site-packages/requests_cache/session.py", line 285, in _resend
#     response = self._send_and_cache(request, actions, cached_response, **kwargs)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/homebrew/lib/python3.12/site-packages/requests_cache/session.py", line 253, in _send_and_cache
#     response = super().send(request, **kwargs)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/homebrew/lib/python3.12/site-packages/fastf1/req.py", line 125, in send
#     lim.limit()
#   File "/opt/homebrew/lib/python3.12/site-packages/fastf1/req.py", line 102, in limit
#     raise RateLimitExceededError(self._info)
# fastf1.req.RateLimitExceededError: ergast.com: 200 calls/h
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 19 drivers: ['1', '55', '11', '4', '16', '81', '63', '22', '18', '14', '44', '23', '77', '20', '31', '27', '10', '3', '24']
# core        WARNING 	Failed to preserve data type for column 'X' while merging telemetry.
# core        WARNING 	Failed to preserve data type for column 'Y' while merging telemetry.
# core        WARNING 	Failed to preserve data type for column 'Z' while merging telemetry.
# 82it [01:08,  1.30it/s]core           INFO 	Loading data for Japanese Grand Prix - Qualifying [v3.3.7]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# Request for URL https://ergast.com/api/f1/2024/4/qualifying.json failed; using cached response
# Traceback (most recent call last):
#   File "/opt/homebrew/lib/python3.12/site-packages/requests_cache/session.py", line 285, in _resend
#     response = self._send_and_cache(request, actions, cached_response, **kwargs)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/homebrew/lib/python3.12/site-packages/requests_cache/session.py", line 253, in _send_and_cache
#     response = super().send(request, **kwargs)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/homebrew/lib/python3.12/site-packages/fastf1/req.py", line 125, in send
#     lim.limit()
#   File "/opt/homebrew/lib/python3.12/site-packages/fastf1/req.py", line 102, in limit
#     raise RateLimitExceededError(self._info)
# fastf1.req.RateLimitExceededError: ergast.com: 200 calls/h
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['1', '11', '4', '55', '14', '81', '44', '16', '63', '22', '3', '27', '77', '23', '31', '18', '10', '20', '2', '24']
# core        WARNING 	Failed to preserve data type for column 'X' while merging telemetry.
# core        WARNING 	Failed to preserve data type for column 'Y' while merging telemetry.
# core        WARNING 	Failed to preserve data type for column 'Z' while merging telemetry.
# 83it [01:09,  1.31it/s]core           INFO 	Loading data for Chinese Grand Prix - Qualifying [v3.3.7]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# Request for URL https://ergast.com/api/f1/2024/5/qualifying.json failed; using cached response
# Traceback (most recent call last):
#   File "/opt/homebrew/lib/python3.12/site-packages/requests_cache/session.py", line 285, in _resend
#     response = self._send_and_cache(request, actions, cached_response, **kwargs)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/homebrew/lib/python3.12/site-packages/requests_cache/session.py", line 253, in _send_and_cache
#     response = super().send(request, **kwargs)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/homebrew/lib/python3.12/site-packages/fastf1/req.py", line 125, in send
#     lim.limit()
#   File "/opt/homebrew/lib/python3.12/site-packages/fastf1/req.py", line 102, in limit
#     raise RateLimitExceededError(self._info)
# fastf1.req.RateLimitExceededError: ergast.com: 200 calls/h
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['1', '11', '14', '4', '81', '16', '55', '63', '27', '77', '18', '3', '31', '23', '10', '24', '20', '44', '22', '2']
# core        WARNING 	Failed to preserve data type for column 'X' while merging telemetry.
# core        WARNING 	Failed to preserve data type for column 'Y' while merging telemetry.
# core        WARNING 	Failed to preserve data type for column 'Z' while merging telemetry.
# 84it [01:10,  1.28it/s]core           INFO 	Loading data for Miami Grand Prix - Qualifying [v3.3.7]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# Request for URL https://ergast.com/api/f1/2024/6/qualifying.json failed; using cached response
# Traceback (most recent call last):
#   File "/opt/homebrew/lib/python3.12/site-packages/requests_cache/session.py", line 285, in _resend
#     response = self._send_and_cache(request, actions, cached_response, **kwargs)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/homebrew/lib/python3.12/site-packages/requests_cache/session.py", line 253, in _send_and_cache
#     response = super().send(request, **kwargs)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/homebrew/lib/python3.12/site-packages/fastf1/req.py", line 125, in send
#     lim.limit()
#   File "/opt/homebrew/lib/python3.12/site-packages/fastf1/req.py", line 102, in limit
#     raise RateLimitExceededError(self._info)
# fastf1.req.RateLimitExceededError: ergast.com: 200 calls/h
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['1', '16', '55', '11', '4', '81', '63', '44', '27', '22', '18', '10', '31', '23', '14', '77', '2', '3', '20', '24']
# core        WARNING 	Failed to preserve data type for column 'X' while merging telemetry.
# core        WARNING 	Failed to preserve data type for column 'Y' while merging telemetry.
# core        WARNING 	Failed to preserve data type for column 'Z' while merging telemetry.
# 85it [01:11,  1.32it/s]core           INFO 	Loading data for Emilia Romagna Grand Prix - Qualifying [v3.3.7]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# Request for URL https://ergast.com/api/f1/2024/7/qualifying.json failed; using cached response
# Traceback (most recent call last):
#   File "/opt/homebrew/lib/python3.12/site-packages/requests_cache/session.py", line 285, in _resend
#     response = self._send_and_cache(request, actions, cached_response, **kwargs)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/homebrew/lib/python3.12/site-packages/requests_cache/session.py", line 253, in _send_and_cache
#     response = super().send(request, **kwargs)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/homebrew/lib/python3.12/site-packages/fastf1/req.py", line 125, in send
#     lim.limit()
#   File "/opt/homebrew/lib/python3.12/site-packages/fastf1/req.py", line 102, in limit
#     raise RateLimitExceededError(self._info)
# fastf1.req.RateLimitExceededError: ergast.com: 200 calls/h
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# core        WARNING 	Driver  2: Lap timing integrity check failed for 1 lap(s)
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['1', '81', '4', '16', '55', '63', '22', '44', '3', '27', '11', '31', '18', '23', '10', '77', '24', '20', '14', '2']
# core        WARNING 	Failed to preserve data type for column 'X' while merging telemetry.
# core        WARNING 	Failed to preserve data type for column 'Y' while merging telemetry.
# core        WARNING 	Failed to preserve data type for column 'Z' while merging telemetry.
# 86it [01:11,  1.29it/s]core           INFO 	Loading data for Monaco Grand Prix - Qualifying [v3.3.7]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# Request for URL https://ergast.com/api/f1/2024/8/qualifying.json failed; using cached response
# Traceback (most recent call last):
#   File "/opt/homebrew/lib/python3.12/site-packages/requests_cache/session.py", line 285, in _resend
#     response = self._send_and_cache(request, actions, cached_response, **kwargs)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/homebrew/lib/python3.12/site-packages/requests_cache/session.py", line 253, in _send_and_cache
#     response = super().send(request, **kwargs)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/homebrew/lib/python3.12/site-packages/fastf1/req.py", line 125, in send
#     lim.limit()
#   File "/opt/homebrew/lib/python3.12/site-packages/fastf1/req.py", line 102, in limit
#     raise RateLimitExceededError(self._info)
# fastf1.req.RateLimitExceededError: ergast.com: 200 calls/h
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# core        WARNING 	Driver  3: Lap timing integrity check failed for 1 lap(s)
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['16', '81', '55', '4', '63', '1', '44', '22', '23', '10', '31', '27', '3', '18', '20', '14', '2', '11', '77', '24']
# 87it [01:12,  1.20it/s]

# %%
df_track_data = pd.concat(all_track_data)

# %%
df_track_data
# Out:
#                 x            y  round_number  year             gp_name
# 0     1171.680323 -1174.730276             2  2020  Styrian Grand Prix
# 1     1011.455297 -1220.533564             2  2020  Styrian Grand Prix
# 2      864.175935 -1263.110428             2  2020  Styrian Grand Prix
# 3      699.986423 -1310.983222             2  2020  Styrian Grand Prix
# 4      534.779612 -1357.873620             2  2020  Styrian Grand Prix
# ..            ...          ...           ...   ...                 ...
# 264 -10471.544323   299.106168             8  2024   Monaco Grand Prix
# 265 -10386.691509   405.172186             8  2024   Monaco Grand Prix
# 266 -10229.713803   587.605735             8  2024   Monaco Grand Prix
# 267 -10098.899049   736.805266             8  2024   Monaco Grand Prix
# 268  -9959.599013   893.075865             8  2024   Monaco Grand Prix
#
# [30170 rows x 5 columns]

# %% [markdown]
# Add the circuit keys

# %%
gp_to_circuit = {'Abu Dhabi Grand Prix' : 'yas_marina' ,
 'Australian Grand Prix' : 'albert_park',
 'Austrian Grand Prix' : 'red_bull_ring',
'Styrian Grand Prix' : 'red_bull_ring',
 'Azerbaijan Grand Prix': 'baku',
 'Bahrain Grand Prix': 'bahrain',
 'Belgian Grand Prix': 'spa',
 'British Grand Prix': 'silverstone',
 'Canadian Grand Prix': 'villeneuve',
 'Chinese Grand Prix': 'shanghai',
 'Dutch Grand Prix': 'zandvoort',
 'Eifel Grand Prix': 'nurburgring',
 'Emilia Romagna Grand Prix': 'imola',
 'French Grand Prix': 'ricard',
 'Hungarian Grand Prix': 'hungaroring',
 'Italian Grand Prix': 'monza',
 'Japanese Grand Prix': 'suzuka',
 'Las Vegas Grand Prix': 'vegas',
 'Mexico City Grand Prix': 'rodriguez',
 'Miami Grand Prix': 'miami',
 'Monaco Grand Prix': 'monaco',
 'Portuguese Grand Prix': 'portimao',
 'Qatar Grand Prix': 'losail',
 'Russian Grand Prix': 'sochi',
 'Saudi Arabian Grand Prix': 'jeddah',
 'Singapore Grand Prix': 'marina_bay',
 'Spanish Grand Prix': 'catalunya',
 'São Paulo Grand Prix': 'interlagos',
 'Turkish Grand Prix': 'istanbul',
 'Tuscan Grand Prix': 'mugello',
 'United States Grand Prix': 'americas'}

# %%
df_track_data['circuit_code'] = df_track_data['gp_name'].map(gp_to_circuit)

# %%
df_track_data.head()
# Out:
#              x            y  round_number  year             gp_name  \
# 0  1171.680323 -1174.730276             2  2020  Styrian Grand Prix
# 1  1011.455297 -1220.533564             2  2020  Styrian Grand Prix
# 2   864.175935 -1263.110428             2  2020  Styrian Grand Prix
# 3   699.986423 -1310.983222             2  2020  Styrian Grand Prix
# 4   534.779612 -1357.873620             2  2020  Styrian Grand Prix
#
#     circuit_code
# 0  red_bull_ring
# 1  red_bull_ring
# 2  red_bull_ring
# 3  red_bull_ring
# 4  red_bull_ring

# %% [markdown]
# Add the track geo information

# %%
all_circuits = []
unique_circuit_ids = set()

for year in range(2020, 2025):
    temp_df = ergast.get_circuits(season=year, result_type='pandas')[["circuitId", "circuitName", "long", "lat", "locality", "country"]]
    
    temp_df = temp_df[~temp_df['circuitId'].isin(unique_circuit_ids)]
    unique_circuit_ids.update(temp_df['circuitId'])
    
    all_circuits.append(temp_df)

all_circuits_df = pd.concat(all_circuits).reset_index(drop=True)
# Out:
# Request for URL https://ergast.com/api/f1/2020/circuits.json failed; using cached response
# Traceback (most recent call last):
#   File "/opt/homebrew/lib/python3.12/site-packages/requests_cache/session.py", line 285, in _resend
#     response = self._send_and_cache(request, actions, cached_response, **kwargs)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/homebrew/lib/python3.12/site-packages/requests_cache/session.py", line 253, in _send_and_cache
#     response = super().send(request, **kwargs)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/homebrew/lib/python3.12/site-packages/fastf1/req.py", line 125, in send
#     lim.limit()
#   File "/opt/homebrew/lib/python3.12/site-packages/fastf1/req.py", line 102, in limit
#     raise RateLimitExceededError(self._info)
# fastf1.req.RateLimitExceededError: ergast.com: 200 calls/h
# Request for URL https://ergast.com/api/f1/2021/circuits.json failed; using cached response
# Traceback (most recent call last):
#   File "/opt/homebrew/lib/python3.12/site-packages/requests_cache/session.py", line 285, in _resend
#     response = self._send_and_cache(request, actions, cached_response, **kwargs)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/homebrew/lib/python3.12/site-packages/requests_cache/session.py", line 253, in _send_and_cache
#     response = super().send(request, **kwargs)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/homebrew/lib/python3.12/site-packages/fastf1/req.py", line 125, in send
#     lim.limit()
#   File "/opt/homebrew/lib/python3.12/site-packages/fastf1/req.py", line 102, in limit
#     raise RateLimitExceededError(self._info)
# fastf1.req.RateLimitExceededError: ergast.com: 200 calls/h
# Request for URL https://ergast.com/api/f1/2022/circuits.json failed; using cached response
# Traceback (most recent call last):
#   File "/opt/homebrew/lib/python3.12/site-packages/requests_cache/session.py", line 285, in _resend
#     response = self._send_and_cache(request, actions, cached_response, **kwargs)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/homebrew/lib/python3.12/site-packages/requests_cache/session.py", line 253, in _send_and_cache
#     response = super().send(request, **kwargs)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/homebrew/lib/python3.12/site-packages/fastf1/req.py", line 125, in send
#     lim.limit()
#   File "/opt/homebrew/lib/python3.12/site-packages/fastf1/req.py", line 102, in limit
#     raise RateLimitExceededError(self._info)
# fastf1.req.RateLimitExceededError: ergast.com: 200 calls/h
# Request for URL https://ergast.com/api/f1/2023/circuits.json failed; using cached response
# Traceback (most recent call last):
#   File "/opt/homebrew/lib/python3.12/site-packages/requests_cache/session.py", line 285, in _resend
#     response = self._send_and_cache(request, actions, cached_response, **kwargs)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/homebrew/lib/python3.12/site-packages/requests_cache/session.py", line 253, in _send_and_cache
#     response = super().send(request, **kwargs)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/homebrew/lib/python3.12/site-packages/fastf1/req.py", line 125, in send
#     lim.limit()
#   File "/opt/homebrew/lib/python3.12/site-packages/fastf1/req.py", line 102, in limit
#     raise RateLimitExceededError(self._info)
# fastf1.req.RateLimitExceededError: ergast.com: 200 calls/h
# Request for URL https://ergast.com/api/f1/2024/circuits.json failed; using cached response
# Traceback (most recent call last):
#   File "/opt/homebrew/lib/python3.12/site-packages/requests_cache/session.py", line 285, in _resend
#     response = self._send_and_cache(request, actions, cached_response, **kwargs)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/homebrew/lib/python3.12/site-packages/requests_cache/session.py", line 253, in _send_and_cache
#     response = super().send(request, **kwargs)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/homebrew/lib/python3.12/site-packages/fastf1/req.py", line 125, in send
#     lim.limit()
#   File "/opt/homebrew/lib/python3.12/site-packages/fastf1/req.py", line 102, in limit
#     raise RateLimitExceededError(self._info)
# fastf1.req.RateLimitExceededError: ergast.com: 200 calls/h

# %%
df_circuits_geo = pd.read_csv("../static/data/circuit_geo.csv")
df_circuits = pd.read_parquet("../static/data/all_tracks_new.parquet")
circuit_data = df_circuits_geo.merge(df_circuits[["round_number", "year", "gp_name", "circuit_code"]].drop_duplicates(), left_on='circuitId', right_on='circuit_code', how='right')

# %%
df_circuits_geo
# Out:
#         circuitId                           circuitName       long      lat  \
# 0         bahrain         Bahrain International Circuit   50.51060  26.0325
# 1       catalunya        Circuit de Barcelona-Catalunya    2.26111  41.5700
# 2     hungaroring                           Hungaroring   19.24860  47.5789
# 3           imola         Autodromo Enzo e Dino Ferrari   11.71670  44.3439
# 4        istanbul                         Istanbul Park   29.40500  40.9517
# 5           monza          Autodromo Nazionale di Monza    9.28111  45.6156
# 6         mugello  Autodromo Internazionale del Mugello   11.37190  43.9975
# 7     nurburgring                           Nürburgring    6.94750  50.3356
# 8        portimao    Autódromo Internacional do Algarve   -8.62670  37.2270
# 9   red_bull_ring                         Red Bull Ring   14.76470  47.2197
# 10    silverstone                   Silverstone Circuit   -1.01694  52.0786
# 11          sochi                        Sochi Autodrom   39.95780  43.4057
# 12            spa          Circuit de Spa-Francorchamps    5.97139  50.4372
# 13     yas_marina                    Yas Marina Circuit   54.60310  24.4672
# 14       americas               Circuit of the Americas  -97.64110  30.1328
# 15           baku                     Baku City Circuit   49.85330  40.3725
# 16     interlagos            Autódromo José Carlos Pace  -46.69970 -23.7036
# 17         jeddah               Jeddah Corniche Circuit   39.10440  21.6319
# 18         losail          Losail International Circuit   51.45420  25.4900
# 19         monaco                     Circuit de Monaco    7.42056  43.7347
# 20         ricard                   Circuit Paul Ricard    5.79167  43.2506
# 21      rodriguez          Autódromo Hermanos Rodríguez  -99.09070  19.4042
# 22      zandvoort                Circuit Park Zandvoort    4.54092  52.3888
# 23    albert_park        Albert Park Grand Prix Circuit  144.96800 -37.8497
# 24     marina_bay             Marina Bay Street Circuit  103.86400   1.2914
# 25          miami         Miami International Autodrome  -80.23890  25.9581
# 26         suzuka                        Suzuka Circuit  136.54100  34.8431
# 27     villeneuve             Circuit Gilles Villeneuve  -73.52280  45.5000
# 28          vegas        Las Vegas Strip Street Circuit -115.17300  36.1147
# 29       shanghai        Shanghai International Circuit  121.22000  31.3389
#
#         locality        country
# 0         Sakhir        Bahrain
# 1       Montmeló          Spain
# 2       Budapest        Hungary
# 3          Imola          Italy
# 4       Istanbul         Turkey
# 5          Monza          Italy
# 6        Mugello          Italy
# 7        Nürburg        Germany
# 8       Portimão       Portugal
# 9      Spielberg        Austria
# 10   Silverstone             UK
# 11         Sochi         Russia
# 12           Spa        Belgium
# 13     Abu Dhabi            UAE
# 14        Austin            USA
# 15          Baku     Azerbaijan
# 16     São Paulo         Brazil
# 17        Jeddah   Saudi Arabia
# 18     Al Daayen          Qatar
# 19   Monte-Carlo         Monaco
# 20  Le Castellet         France
# 21   Mexico City         Mexico
# 22     Zandvoort    Netherlands
# 23     Melbourne      Australia
# 24    Marina Bay      Singapore
# 25         Miami            USA
# 26        Suzuka          Japan
# 27      Montreal         Canada
# 28     Las Vegas  United States
# 29      Shanghai          China

# %%
circuit_data = circuit_data.sort_values(by=["year", "round_number"], axis=0)

# %%
circuit_data.to_csv("../static/data/circuit_data.csv", index=False)

# %%
pd.read_csv("../static/data/circuit_data.csv")
# Out:
#         circuitId                     circuitName       long      lat  \
# 0   red_bull_ring                   Red Bull Ring   14.76470  47.2197
# 1     hungaroring                     Hungaroring   19.24860  47.5789
# 2     silverstone             Silverstone Circuit   -1.01694  52.0786
# 3       catalunya  Circuit de Barcelona-Catalunya    2.26111  41.5700
# 4             spa    Circuit de Spa-Francorchamps    5.97139  50.4372
# ..            ...                             ...        ...      ...
# 82         suzuka                  Suzuka Circuit  136.54100  34.8431
# 83       shanghai  Shanghai International Circuit  121.22000  31.3389
# 84          miami   Miami International Autodrome  -80.23890  25.9581
# 85          imola   Autodromo Enzo e Dino Ferrari   11.71670  44.3439
# 86         monaco               Circuit de Monaco    7.42056  43.7347
#
#        locality  country  round_number  year                    gp_name  \
# 0     Spielberg  Austria             2  2020         Styrian Grand Prix
# 1      Budapest  Hungary             3  2020       Hungarian Grand Prix
# 2   Silverstone       UK             4  2020         British Grand Prix
# 3      Montmeló    Spain             6  2020         Spanish Grand Prix
# 4           Spa  Belgium             7  2020         Belgian Grand Prix
# ..          ...      ...           ...   ...                        ...
# 82       Suzuka    Japan             4  2024        Japanese Grand Prix
# 83     Shanghai    China             5  2024         Chinese Grand Prix
# 84        Miami      USA             6  2024           Miami Grand Prix
# 85        Imola    Italy             7  2024  Emilia Romagna Grand Prix
# 86  Monte-Carlo   Monaco             8  2024          Monaco Grand Prix
#
#      circuit_code
# 0   red_bull_ring
# 1     hungaroring
# 2     silverstone
# 3       catalunya
# 4             spa
# ..            ...
# 82         suzuka
# 83       shanghai
# 84          miami
# 85          imola
# 86         monaco
#
# [87 rows x 10 columns]

# %% [markdown]
# Save to parquet

# %%
df_track_data.to_parquet("../static/data/all_tracks_new.parquet",index=False)
