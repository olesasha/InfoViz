# %% [markdown]
# ### This Notebook scrapes all tracks and saves the pos data into a parquet-file

# %%
import fastf1 as ff1
import numpy as np
import pandas as pd
from tqdm import tqdm

# %%
data = ff1.get_event_schedule(2020)

# %%
data["EventName"].unique
# Out:
# <bound method Series.unique of 0               Pre-Season Test 1
# 1               Pre-Season Test 2
# 2             Austrian Grand Prix
# 3              Styrian Grand Prix
# 4            Hungarian Grand Prix
# 5              British Grand Prix
# 6     70th Anniversary Grand Prix
# 7              Spanish Grand Prix
# 8              Belgian Grand Prix
# 9              Italian Grand Prix
# 10              Tuscan Grand Prix
# 11             Russian Grand Prix
# 12               Eifel Grand Prix
# 13          Portuguese Grand Prix
# 14      Emilia Romagna Grand Prix
# 15             Turkish Grand Prix
# 16             Bahrain Grand Prix
# 17              Sakhir Grand Prix
# 18           Abu Dhabi Grand Prix
# Name: EventName, dtype: object>

# %%
data["Location"].unique
# Out:
# <bound method Series.unique of 0             Barcelona
# 1             Barcelona
# 2             Spielberg
# 3             Spielberg
# 4              Budapest
# 5           Silverstone
# 6           Silverstone
# 7             Barcelona
# 8     Spa-Francorchamps
# 9                 Monza
# 10              Mugello
# 11                Sochi
# 12          Nürburgring
# 13             Portimão
# 14                Imola
# 15             Istanbul
# 16               Sakhir
# 17               Sakhir
# 18           Yas Island
# Name: Location, dtype: object>

# %% [markdown]
# Get all GPs from the years 2020 to 2024

# %%
all_gps = []
for year in range(2020,2025):
    temp_df = pd.DataFrame(ff1.get_event_schedule(year)[["RoundNumber", "EventName"]])
    temp_df["year"] = year
    all_gps.append(temp_df)


df_all_gps = pd.concat(all_gps)

# %%
# remove one-off races
remove = ['70th Anniversary Grand Prix', 'Styrian Grand Prix', 'Sakhir Grand Prix']
df_all_gps = df_all_gps.loc[~df_all_gps["EventName"].isin(remove)]

# %% [markdown]
# Drop testing events

# %%
df_all_gps = df_all_gps.replace({0:None},regex=True)
df_all_gps = df_all_gps.dropna()

# %% [markdown]
# Scrape the track data for every track

# %%
# Hilfsfunktion um Positionen gleich richtig zu rotieren
def rotate(xy, *, angle):
    rot_mat = np.array(
        [[np.cos(angle), np.sin(angle)], [-np.sin(angle), np.cos(angle)]]
    )
    return np.matmul(xy, rot_mat)

# %%
df_all_gps.head()
# Out:
#   RoundNumber             EventName  year
# 2           1   Austrian Grand Prix  2020
# 4           3  Hungarian Grand Prix  2020
# 5           4    British Grand Prix  2020
# 7           6    Spanish Grand Prix  2020
# 8           7    Belgian Grand Prix  2020

# %%
all_track_data = []
for _,gp_data in tqdm(df_all_gps.iterrows()):
    year = gp_data["year"]
    gp = gp_data["RoundNumber"]
    gp_name = gp_data["EventName"]

    session = ff1.get_session(year,gp,"Q")
    session.load()
    df_temp_pos_data = session.laps.pick_fastest().get_pos_data()
    # add the first row to end to make the lap complete
    temp_first_row = df_temp_pos_data.iloc[:1,:]
    df_temp_pos_data = pd.concat([df_temp_pos_data,temp_first_row])
    
    track = df_temp_pos_data.loc[:, ("X", "Y")].to_numpy()

    circuit_info = session.get_circuit_info()
    # Convert the rotation angle from degrees to radian.
    track_angle = circuit_info.rotation / 180 * np.pi

    # Rotate and plot the track map.
    rotated_track = rotate(track, angle=track_angle)
    
    df_temp_track_data = pd.DataFrame(rotated_track, columns=["x", "y"])
    
    df_temp_track_data["round_number"] = gp
    df_temp_track_data["year"] = year
    df_temp_track_data["gp_name"] = gp_name
    all_track_data.append(df_temp_track_data)

df_track_data = pd.concat(all_track_data)
# Out:
# 0it [00:00, ?it/s]core           INFO 	Loading data for Austrian Grand Prix - Qualifying [v3.3.7]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['77', '44', '33', '4', '23', '11', '16', '55', '18', '3', '5', '10', '26', '31', '8', '20', '63', '99', '7', '6']
# 1it [00:01,  1.16s/it]core           INFO 	Loading data for Hungarian Grand Prix - Qualifying [v3.3.7]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['44', '77', '18', '11', '5', '16', '33', '4', '55', '10', '3', '63', '23', '31', '6', '20', '26', '8', '99', '7']
# 2it [00:04,  2.63s/it]core           INFO 	Loading data for British Grand Prix - Qualifying [v3.3.7]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['44', '77', '33', '16', '4', '18', '55', '3', '31', '5', '10', '23', '27', '26', '63', '20', '99', '7', '8', '6']
# 3it [00:06,  2.38s/it]core           INFO 	Loading data for Spanish Grand Prix - Qualifying [v3.3.7]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['44', '77', '33', '11', '18', '23', '55', '4', '16', '10', '5', '26', '3', '7', '31', '20', '8', '63', '6', '99']
# core        WARNING 	Failed to preserve data type for column 'X' while merging telemetry.
# core        WARNING 	Failed to preserve data type for column 'Y' while merging telemetry.
# core        WARNING 	Failed to preserve data type for column 'Z' while merging telemetry.
# 4it [00:08,  2.12s/it]core           INFO 	Loading data for Belgian Grand Prix - Qualifying [v3.3.7]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['44', '77', '33', '3', '23', '31', '55', '11', '18', '4', '26', '10', '16', '5', '63', '7', '8', '99', '6', '20']
# 5it [00:10,  1.86s/it]core           INFO 	Loading data for Italian Grand Prix - Qualifying [v3.3.7]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['44', '77', '55', '11', '33', '4', '3', '18', '23', '10', '26', '31', '16', '7', '20', '8', '5', '99', '63', '6']
# 6it [00:11,  1.78s/it]core           INFO 	Loading data for Tuscan Grand Prix - Qualifying [v3.3.7]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['44', '77', '33', '23', '16', '11', '18', '3', '55', '31', '4', '26', '7', '5', '8', '10', '99', '63', '6', '20']
# core        WARNING 	Failed to preserve data type for column 'X' while merging telemetry.
# core        WARNING 	Failed to preserve data type for column 'Y' while merging telemetry.
# core        WARNING 	Failed to preserve data type for column 'Z' while merging telemetry.
# 7it [00:13,  1.72s/it]core           INFO 	Loading data for Russian Grand Prix - Qualifying [v3.3.7]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['44', '33', '77', '11', '3', '55', '31', '4', '10', '23', '16', '26', '18', '63', '5', '8', '99', '20', '6', '7']
# 8it [00:14,  1.67s/it]core           INFO 	Loading data for Eifel Grand Prix - Qualifying [v3.3.7]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['77', '44', '33', '16', '23', '3', '31', '4', '11', '55', '5', '10', '26', '99', '20', '8', '63', '6', '7', '27']
# 9it [00:16,  1.64s/it]core           INFO 	Loading data for Portuguese Grand Prix - Qualifying [v3.3.7]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['44', '77', '33', '16', '11', '23', '55', '4', '10', '3', '31', '18', '26', '63', '5', '7', '99', '8', '20', '6']
# core        WARNING 	Failed to preserve data type for column 'X' while merging telemetry.
# core        WARNING 	Failed to preserve data type for column 'Y' while merging telemetry.
# core        WARNING 	Failed to preserve data type for column 'Z' while merging telemetry.
# 10it [00:18,  1.75s/it]core           INFO 	Loading data for Emilia Romagna Grand Prix - Qualifying [v3.3.7]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['77', '44', '33', '10', '3', '23', '16', '26', '4', '55', '11', '31', '63', '5', '18', '8', '20', '7', '6', '99']
# 11it [00:20,  1.73s/it]core           INFO 	Loading data for Turkish Grand Prix - Qualifying [v3.3.7]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['18', '33', '11', '23', '3', '44', '31', '7', '77', '99', '4', '5', '55', '16', '10', '20', '26', '63', '8', '6']
# 12it [00:22,  1.87s/it]core           INFO 	Loading data for Bahrain Grand Prix - Qualifying [v3.3.7]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['44', '77', '33', '23', '11', '3', '31', '10', '4', '26', '5', '16', '18', '63', '55', '99', '7', '20', '8', '6']
# 13it [00:24,  1.86s/it]core           INFO 	Loading data for Abu Dhabi Grand Prix - Qualifying [v3.3.7]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['33', '77', '44', '4', '23', '55', '26', '18', '16', '10', '31', '3', '5', '99', '11', '7', '20', '63', '51', '6']
# core        WARNING 	Failed to preserve data type for column 'X' while merging telemetry.
# core        WARNING 	Failed to preserve data type for column 'Y' while merging telemetry.
# core        WARNING 	Failed to preserve data type for column 'Z' while merging telemetry.
# 14it [00:25,  1.83s/it]core           INFO 	Loading data for Bahrain Grand Prix - Qualifying [v3.3.7]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['33', '44', '77', '16', '10', '3', '4', '55', '14', '18', '11', '99', '22', '7', '63', '31', '6', '5', '47', '9']
# core        WARNING 	Failed to preserve data type for column 'X' while merging telemetry.
# core        WARNING 	Failed to preserve data type for column 'Y' while merging telemetry.
# core        WARNING 	Failed to preserve data type for column 'Z' while merging telemetry.
# 15it [00:27,  1.79s/it]core           INFO 	Loading data for Emilia Romagna Grand Prix - Qualifying [v3.3.7]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['44', '11', '33', '16', '10', '3', '4', '77', '31', '18', '55', '63', '5', '6', '14', '7', '99', '47', '9', '22']
# core        WARNING 	Failed to preserve data type for column 'X' while merging telemetry.
# core        WARNING 	Failed to preserve data type for column 'Y' while merging telemetry.
# core        WARNING 	Failed to preserve data type for column 'Z' while merging telemetry.
# 16it [00:29,  1.78s/it]core           INFO 	Loading data for Portuguese Grand Prix - Qualifying [v3.3.7]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['77', '44', '33', '11', '55', '31', '4', '16', '10', '5', '63', '99', '14', '22', '7', '3', '18', '6', '47', '9']
# 17it [00:30,  1.76s/it]core           INFO 	Loading data for Spanish Grand Prix - Qualifying [v3.3.7]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['44', '33', '77', '16', '31', '55', '3', '11', '4', '14', '18', '10', '5', '99', '63', '22', '7', '47', '6', '9']
# 18it [00:32,  1.77s/it]core           INFO 	Loading data for Monaco Grand Prix - Qualifying [v3.3.7]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# core        WARNING 	No lap data for driver 47
# core        WARNING 	Driver  5: Lap timing integrity check failed for 1 lap(s)
# core        WARNING 	Failed to perform lap accuracy check - all laps marked as inaccurate (driver 47)
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['16', '33', '77', '55', '4', '10', '44', '5', '11', '99', '31', '3', '18', '7', '63', '22', '14', '6', '9', '47']
# core        WARNING 	Failed to preserve data type for column 'X' while merging telemetry.
# core        WARNING 	Failed to preserve data type for column 'Y' while merging telemetry.
# core        WARNING 	Failed to preserve data type for column 'Z' while merging telemetry.
# 19it [00:34,  1.76s/it]core           INFO 	Loading data for Azerbaijan Grand Prix - Qualifying [v3.3.7]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['16', '44', '33', '10', '55', '4', '11', '22', '14', '77', '5', '31', '3', '7', '63', '6', '47', '9', '18', '99']
# 20it [00:36,  1.80s/it]core           INFO 	Loading data for French Grand Prix - Qualifying [v3.3.7]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['33', '44', '77', '11', '55', '10', '16', '4', '14', '3', '31', '5', '99', '63', '47', '6', '7', '9', '18', '22']
# core        WARNING 	Failed to preserve data type for column 'X' while merging telemetry.
# core        WARNING 	Failed to preserve data type for column 'Y' while merging telemetry.
# core        WARNING 	Failed to preserve data type for column 'Z' while merging telemetry.
# 21it [00:37,  1.71s/it]core           INFO 	Loading data for Austrian Grand Prix - Qualifying [v3.3.7]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['33', '4', '11', '44', '77', '10', '22', '5', '63', '18', '55', '16', '3', '14', '99', '7', '31', '6', '47', '9']
# core        WARNING 	Failed to preserve data type for column 'X' while merging telemetry.
# core        WARNING 	Failed to preserve data type for column 'Y' while merging telemetry.
# core        WARNING 	Failed to preserve data type for column 'Z' while merging telemetry.
# 22it [00:39,  1.75s/it]core           INFO 	Loading data for British Grand Prix - Qualifying [v3.3.7]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['44', '33', '77', '16', '11', '4', '3', '63', '55', '5', '14', '10', '31', '99', '18', '22', '7', '6', '47', '9']
# core        WARNING 	Failed to preserve data type for column 'X' while merging telemetry.
# core        WARNING 	Failed to preserve data type for column 'Y' while merging telemetry.
# core        WARNING 	Failed to preserve data type for column 'Z' while merging telemetry.
# 23it [00:41,  1.63s/it]core           INFO 	Loading data for Hungarian Grand Prix - Qualifying [v3.3.7]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# core        WARNING 	No lap data for driver 47
# core        WARNING 	Failed to perform lap accuracy check - all laps marked as inaccurate (driver 47)
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['44', '77', '33', '11', '10', '4', '16', '31', '14', '5', '3', '18', '7', '99', '55', '22', '63', '6', '9', '47']
# 24it [00:43,  1.77s/it]core           INFO 	Loading data for Belgian Grand Prix - Qualifying [v3.3.7]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['33', '63', '44', '3', '5', '10', '11', '77', '31', '4', '16', '6', '55', '14', '18', '99', '22', '47', '7', '9']
# 25it [00:45,  1.85s/it]core           INFO 	Loading data for Dutch Grand Prix - Qualifying [v3.3.7]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['33', '44', '77', '10', '16', '55', '99', '31', '14', '3', '63', '18', '4', '6', '22', '11', '5', '88', '47', '9']
# core        WARNING 	Failed to preserve data type for column 'X' while merging telemetry.
# core        WARNING 	Failed to preserve data type for column 'Y' while merging telemetry.
# core        WARNING 	Failed to preserve data type for column 'Z' while merging telemetry.
# 26it [00:47,  1.97s/it]core           INFO 	Loading data for Italian Grand Prix - Qualifying [v3.3.7]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# core        WARNING 	Driver 16: Lap timing integrity check failed for 1 lap(s)
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['77', '44', '33', '4', '3', '10', '55', '16', '11', '99', '5', '18', '14', '31', '63', '6', '22', '47', '88', '9']
# core        WARNING 	Failed to preserve data type for column 'X' while merging telemetry.
# core        WARNING 	Failed to preserve data type for column 'Y' while merging telemetry.
# core        WARNING 	Failed to preserve data type for column 'Z' while merging telemetry.
# 27it [00:49,  1.89s/it]core           INFO 	Loading data for Russian Grand Prix - Qualifying [v3.3.7]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['4', '55', '63', '44', '3', '14', '77', '18', '11', '31', '5', '10', '22', '6', '16', '7', '47', '99', '9', '33']
# core        WARNING 	Failed to preserve data type for column 'X' while merging telemetry.
# core        WARNING 	Failed to preserve data type for column 'Y' while merging telemetry.
# core        WARNING 	Failed to preserve data type for column 'Z' while merging telemetry.
# 28it [00:51,  1.88s/it]core           INFO 	Loading data for Turkish Grand Prix - Qualifying [v3.3.7]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['44', '77', '33', '16', '10', '14', '11', '4', '18', '22', '5', '31', '63', '47', '55', '3', '6', '99', '7', '9']
# 29it [00:52,  1.73s/it]core           INFO 	Loading data for United States Grand Prix - Qualifying [v3.3.7]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['33', '44', '11', '77', '16', '55', '3', '4', '10', '22', '31', '5', '99', '14', '63', '18', '6', '7', '47', '9']
# core        WARNING 	Failed to preserve data type for column 'X' while merging telemetry.
# core        WARNING 	Failed to preserve data type for column 'Y' while merging telemetry.
# core        WARNING 	Failed to preserve data type for column 'Z' while merging telemetry.
# 30it [00:53,  1.62s/it]core           INFO 	Loading data for Mexico City Grand Prix - Qualifying [v3.3.7]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['77', '44', '33', '11', '10', '55', '3', '16', '22', '4', '5', '7', '63', '99', '31', '14', '6', '47', '9', '18']
# 31it [00:55,  1.62s/it]core           INFO 	Loading data for São Paulo Grand Prix - Qualifying [v3.3.7]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['44', '33', '77', '11', '10', '55', '16', '4', '3', '14', '31', '5', '22', '7', '99', '18', '6', '63', '47', '9']
# 32it [00:56,  1.59s/it]core           INFO 	Loading data for Qatar Grand Prix - Qualifying [v3.3.7]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['44', '33', '77', '10', '14', '4', '55', '22', '31', '5', '11', '18', '16', '3', '63', '7', '6', '99', '47', '9']
# core        WARNING 	Failed to preserve data type for column 'X' while merging telemetry.
# core        WARNING 	Failed to preserve data type for column 'Y' while merging telemetry.
# core        WARNING 	Failed to preserve data type for column 'Z' while merging telemetry.
# 33it [00:58,  1.62s/it]core           INFO 	Loading data for Saudi Arabian Grand Prix - Qualifying [v3.3.7]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['44', '77', '33', '16', '11', '10', '4', '22', '31', '99', '3', '7', '14', '63', '55', '6', '5', '18', '47', '9']
# core        WARNING 	Failed to preserve data type for column 'X' while merging telemetry.
# core        WARNING 	Failed to preserve data type for column 'Y' while merging telemetry.
# core        WARNING 	Failed to preserve data type for column 'Z' while merging telemetry.
# 34it [01:00,  1.55s/it]core           INFO 	Loading data for Abu Dhabi Grand Prix - Qualifying [v3.3.7]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# core        WARNING 	Driver 22: Lap timing integrity check failed for 1 lap(s)
# core        WARNING 	Driver  3: Lap timing integrity check failed for 1 lap(s)
# core        WARNING 	Driver 18: Lap timing integrity check failed for 1 lap(s)
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['33', '44', '4', '11', '55', '77', '16', '22', '31', '3', '14', '10', '18', '99', '5', '6', '63', '7', '47', '9']
# core        WARNING 	Failed to preserve data type for column 'X' while merging telemetry.
# core        WARNING 	Failed to preserve data type for column 'Y' while merging telemetry.
# core        WARNING 	Failed to preserve data type for column 'Z' while merging telemetry.
# 35it [01:01,  1.51s/it]core           INFO 	Loading data for Bahrain Grand Prix - Qualifying [v3.3.7]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['16', '1', '55', '11', '44', '77', '20', '14', '63', '10', '31', '47', '4', '23', '24', '22', '27', '3', '18', '6']
# 36it [01:03,  1.54s/it]core           INFO 	Loading data for Saudi Arabian Grand Prix - Qualifying [v3.3.7]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# core        WARNING 	Driver 55: Lap timing integrity check failed for 1 lap(s)
# core        WARNING 	Driver 18: Lap timing integrity check failed for 1 lap(s)
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['11', '16', '55', '1', '31', '63', '14', '77', '10', '20', '4', '3', '24', '47', '18', '44', '23', '27', '6', '22']
# core        WARNING 	Failed to preserve data type for column 'X' while merging telemetry.
# core        WARNING 	Failed to preserve data type for column 'Y' while merging telemetry.
# core        WARNING 	Failed to preserve data type for column 'Z' while merging telemetry.
# 37it [01:04,  1.55s/it]core           INFO 	Loading data for Australian Grand Prix - Qualifying [v3.3.7]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['16', '1', '11', '4', '44', '63', '3', '31', '55', '14', '10', '77', '22', '24', '47', '23', '20', '5', '6', '18']
# 38it [01:06,  1.60s/it]core           INFO 	Loading data for Emilia Romagna Grand Prix - Qualifying [v3.3.7]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['1', '16', '4', '20', '14', '3', '11', '77', '5', '55', '63', '47', '44', '24', '18', '22', '10', '6', '31', '23']
# 39it [01:08,  1.71s/it]core           INFO 	Loading data for Miami Grand Prix - Qualifying [v3.3.7]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# core        WARNING 	No lap data for driver 31
# core        WARNING 	Failed to perform lap accuracy check - all laps marked as inaccurate (driver 31)
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['16', '55', '1', '11', '77', '44', '10', '4', '22', '18', '14', '63', '5', '3', '47', '20', '24', '23', '6', '31']
# 40it [01:09,  1.66s/it]core           INFO 	Loading data for Spanish Grand Prix - Qualifying [v3.3.7]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['16', '1', '55', '63', '11', '44', '77', '20', '3', '47', '4', '31', '22', '10', '24', '5', '14', '18', '23', '6']
# core        WARNING 	Failed to preserve data type for column 'X' while merging telemetry.
# core        WARNING 	Failed to preserve data type for column 'Y' while merging telemetry.
# core        WARNING 	Failed to preserve data type for column 'Z' while merging telemetry.
# 41it [01:11,  1.68s/it]core           INFO 	Loading data for Monaco Grand Prix - Qualifying [v3.3.7]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['16', '55', '11', '1', '4', '63', '14', '44', '5', '31', '22', '77', '20', '3', '47', '23', '10', '18', '6', '24']
# 42it [01:13,  1.70s/it]core           INFO 	Loading data for Azerbaijan Grand Prix - Qualifying [v3.3.7]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['16', '11', '1', '55', '63', '10', '44', '22', '5', '14', '4', '3', '31', '24', '77', '20', '23', '6', '18', '47']
# core        WARNING 	Failed to preserve data type for column 'X' while merging telemetry.
# core        WARNING 	Failed to preserve data type for column 'Y' while merging telemetry.
# core        WARNING 	Failed to preserve data type for column 'Z' while merging telemetry.
# 43it [01:15,  1.78s/it]core           INFO 	Loading data for Canadian Grand Prix - Qualifying [v3.3.7]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['1', '14', '55', '44', '20', '47', '31', '63', '3', '24', '77', '23', '11', '4', '16', '10', '5', '18', '6', '22']
# 44it [01:17,  1.77s/it]core           INFO 	Loading data for British Grand Prix - Qualifying [v3.3.7]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['55', '1', '16', '11', '44', '4', '14', '63', '24', '6', '10', '77', '22', '3', '31', '23', '20', '5', '47', '18']
# 45it [01:18,  1.73s/it]core           INFO 	Loading data for Austrian Grand Prix - Qualifying [v3.3.7]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# ...
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['16', '4', '44', '55', '63', '1', '10', '31', '11', '81', '22', '24', '77', '20', '3', '27', '14', '23', '18', '2']
# 75it [02:07,  1.67s/it]core           INFO 	Loading data for Mexico City Grand Prix - Qualifying [v3.3.7]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['16', '55', '1', '3', '11', '44', '81', '63', '77', '24', '10', '27', '14', '23', '22', '31', '20', '18', '4', '2']
# core        WARNING 	Failed to preserve data type for column 'X' while merging telemetry.
# core        WARNING 	Failed to preserve data type for column 'Y' while merging telemetry.
# core        WARNING 	Failed to preserve data type for column 'Z' while merging telemetry.
# 76it [02:09,  1.64s/it]core           INFO 	Loading data for São Paulo Grand Prix - Qualifying [v3.3.7]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['1', '16', '18', '14', '44', '63', '4', '55', '11', '81', '27', '31', '10', '20', '23', '22', '3', '77', '2', '24']
# 77it [02:11,  1.66s/it]core           INFO 	Loading data for Las Vegas Grand Prix - Qualifying [v3.3.7]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['16', '55', '1', '63', '10', '23', '2', '77', '20', '14', '44', '11', '27', '18', '3', '4', '31', '24', '81', '22']
# 78it [02:13,  1.75s/it]core           INFO 	Loading data for Abu Dhabi Grand Prix - Qualifying [v3.3.7]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['1', '16', '81', '63', '4', '22', '14', '27', '11', '10', '44', '31', '18', '23', '3', '55', '20', '77', '24', '2']
# core        WARNING 	Failed to preserve data type for column 'X' while merging telemetry.
# core        WARNING 	Failed to preserve data type for column 'Y' while merging telemetry.
# core        WARNING 	Failed to preserve data type for column 'Z' while merging telemetry.
# 79it [02:14,  1.55s/it]core           INFO 	Loading data for Bahrain Grand Prix - Qualifying [v3.3.7]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['1', '16', '63', '55', '11', '14', '4', '81', '44', '27', '22', '18', '23', '3', '20', '77', '24', '2', '31', '10']
# 80it [02:15,  1.36s/it]core           INFO 	Loading data for Saudi Arabian Grand Prix - Qualifying [v3.3.7]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['1', '16', '11', '14', '81', '4', '63', '44', '22', '18', '38', '23', '20', '3', '27', '77', '31', '10', '2', '24']
# core        WARNING 	Failed to preserve data type for column 'X' while merging telemetry.
# core        WARNING 	Failed to preserve data type for column 'Y' while merging telemetry.
# core        WARNING 	Failed to preserve data type for column 'Z' while merging telemetry.
# 81it [02:16,  1.28s/it]core           INFO 	Loading data for Australian Grand Prix - Qualifying [v3.3.7]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 19 drivers: ['1', '55', '11', '4', '16', '81', '63', '22', '18', '14', '44', '23', '77', '20', '31', '27', '10', '3', '24']
# core        WARNING 	Failed to preserve data type for column 'X' while merging telemetry.
# core        WARNING 	Failed to preserve data type for column 'Y' while merging telemetry.
# core        WARNING 	Failed to preserve data type for column 'Z' while merging telemetry.
# 82it [02:17,  1.20s/it]core           INFO 	Loading data for Japanese Grand Prix - Qualifying [v3.3.7]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['1', '11', '4', '55', '14', '81', '44', '16', '63', '22', '3', '27', '77', '23', '31', '18', '10', '20', '2', '24']
# core        WARNING 	Failed to preserve data type for column 'X' while merging telemetry.
# core        WARNING 	Failed to preserve data type for column 'Y' while merging telemetry.
# core        WARNING 	Failed to preserve data type for column 'Z' while merging telemetry.
# 83it [02:18,  1.14s/it]core           INFO 	Loading data for Chinese Grand Prix - Qualifying [v3.3.7]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['1', '11', '14', '4', '81', '16', '55', '63', '27', '77', '18', '3', '31', '23', '10', '24', '20', '44', '22', '2']
# core        WARNING 	Failed to preserve data type for column 'X' while merging telemetry.
# core        WARNING 	Failed to preserve data type for column 'Y' while merging telemetry.
# core        WARNING 	Failed to preserve data type for column 'Z' while merging telemetry.
# 84it [02:19,  1.12s/it]core           INFO 	Loading data for Miami Grand Prix - Qualifying [v3.3.7]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['1', '16', '55', '11', '4', '81', '63', '44', '27', '22', '18', '10', '31', '23', '14', '77', '2', '3', '20', '24']
# core        WARNING 	Failed to preserve data type for column 'X' while merging telemetry.
# core        WARNING 	Failed to preserve data type for column 'Y' while merging telemetry.
# core        WARNING 	Failed to preserve data type for column 'Z' while merging telemetry.
# 85it [02:20,  1.07s/it]core           INFO 	Loading data for Emilia Romagna Grand Prix - Qualifying [v3.3.7]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# core        WARNING 	Driver  2: Lap timing integrity check failed for 1 lap(s)
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['1', '81', '4', '16', '55', '63', '22', '44', '3', '27', '11', '31', '18', '23', '10', '77', '24', '20', '14', '2']
# core        WARNING 	Failed to preserve data type for column 'X' while merging telemetry.
# core        WARNING 	Failed to preserve data type for column 'Y' while merging telemetry.
# core        WARNING 	Failed to preserve data type for column 'Z' while merging telemetry.
# 86it [02:21,  1.04s/it]core           INFO 	Loading data for Monaco Grand Prix - Qualifying [v3.3.7]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# core        WARNING 	Driver  3: Lap timing integrity check failed for 1 lap(s)
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['16', '81', '55', '4', '63', '1', '44', '22', '23', '10', '31', '27', '3', '18', '20', '14', '2', '11', '77', '24']
# 87it [02:22,  1.04s/it]core           INFO 	Loading data for Canadian Grand Prix - Qualifying [v3.3.7]
# req            INFO 	No cached data found for session_info. Loading data...
# _api           INFO 	Fetching session info data...
# logger      WARNING 	Failed to load session info data!
# req            INFO 	No cached data found for driver_info. Loading data...
# _api           INFO 	Fetching driver list...
# core        WARNING 	Failed to load extended driver information!
# 87it [02:22,  1.64s/it]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[95], line 8
#       5 gp_name = gp_data["EventName"]
#       7 session = ff1.get_session(year,gp,"Q")
# ----> 8 session.load()
#       9 df_temp_pos_data = session.laps.pick_fastest().get_pos_data()
#      10 # add the first row to end to make the lap complete
#
# File /opt/homebrew/lib/python3.12/site-packages/fastf1/core.py:1424, in Session.load(self, laps, telemetry, weather, messages, livedata)
#    1419 _logger.info(f"Loading data for "
#    1420              f"{self.event['EventName']} - {self.name}"
#    1421              f" [v{fastf1.__version__}]")
#    1423 self._load_session_info(livedata=livedata)
# -> 1424 self._load_drivers_results(livedata=livedata)
#    1426 if self.f1_api_support:
#    1427     if laps:
#
# File /opt/homebrew/lib/python3.12/site-packages/fastf1/core.py:2189, in Session._load_drivers_results(self, livedata)
#    2185 # try loading from both sources if they are supported
#    2186 # data is joined afterwards depending on availability
#    2187 if self.f1_api_support:
#    2188     # load driver info from f1 api
# -> 2189     driver_info_f1 = self._drivers_from_f1_api(livedata=livedata)
#    2190 if not self.event.is_testing():
#    2191     # load driver info from ergast
#    2192     driver_info_ergast = self._drivers_results_from_ergast(
#    2193         load_drivers=True, load_results=True
#    2194     )
#
# File /opt/homebrew/lib/python3.12/site-packages/fastf1/core.py:2273, in Session._drivers_from_f1_api(self, livedata)
#    2270         for first, last in zip(driver_info['FirstName'],
#    2271                                driver_info['LastName']):
#    2272             driver_info['FullName'].append(f"{first} {last}")
# -> 2273 return pd.DataFrame(driver_info, index=driver_info['DriverNumber'])
#
# KeyError: 'DriverNumber'

# %%
df_track_data = pd.concat(all_track_data)

# %% [markdown]
# Add the circuit keys

# %%
gp_to_circuit = {'Abu Dhabi Grand Prix' : 'yas_marina' ,
 'Australian Grand Prix' : 'albert_park',
 'Austrian Grand Prix' : 'red_bull_ring',
 'Azerbaijan Grand Prix': 'baku',
 'Bahrain Grand Prix': 'bahrain',
 'Belgian Grand Prix': 'spa',
 'British Grand Prix': 'silverstone',
 'Canadian Grand Prix': 'villeneuve',
 'Chinese Grand Prix': 'shanghai',
 'Dutch Grand Prix': 'zandvoort',
 'Eifel Grand Prix': 'nurburgring',
 'Emilia Romagna Grand Prix': 'imola',
 'French Grand Prix': 'ricard',
 'Hungarian Grand Prix': 'hungaroring',
 'Italian Grand Prix': 'monza',
 'Japanese Grand Prix': 'suzuka',
 'Las Vegas Grand Prix': 'vegas',
 'Mexico City Grand Prix': 'rodriguez',
 'Miami Grand Prix': 'miami',
 'Monaco Grand Prix': 'monaco',
 'Portuguese Grand Prix': 'portimao',
 'Qatar Grand Prix': 'losail',
 'Russian Grand Prix': 'sochi',
 'Saudi Arabian Grand Prix': 'jeddah',
 'Singapore Grand Prix': 'marina_bay',
 'Spanish Grand Prix': 'catalunya',
 'São Paulo Grand Prix': 'interlagos',
 'Turkish Grand Prix': 'istanbul',
 'Tuscan Grand Prix': 'mugello',
 'United States Grand Prix': 'americas'}

# %%
df_track_data['circuit_code'] = df_track_data['gp_name'].map(gp_to_circuit)

# %% [markdown]
# Save to parquet

# %%
df_track_data.to_parquet("../static/data/all_tracks_new.parquet",index=False)
