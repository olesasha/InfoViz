# %%
import fastf1 as ff1
import pandas as pd

# %%
all_gps = []
for year in range(2020,2025):
    temp_df = pd.DataFrame(ff1.get_event_schedule(year)["RoundNumber"])
    temp_df["year"] = year
    if year != 2024:
        all_gps.append(temp_df)
    else:
        all_gps.append(temp_df.loc[:8])




df_all_gps = pd.concat(all_gps)
# Out:
# req         WARNING 	DEFAULT CACHE ENABLED! (10.79 GB) /Users/max/Library/Caches/fastf1

# %%
df_all_gps = df_all_gps.replace({0:None})
df_all_gps = df_all_gps.dropna()
df_all_gps = df_all_gps.reset_index(drop=True)

# %%
all_laps_data = []
for _,gp_data in df_all_gps.iterrows():
    year = gp_data["year"]
    gp = gp_data["RoundNumber"]

    session = ff1.get_session(year,gp,"R")
    session.load()

    for driver in session.drivers:
        
        try:
            df_laps = session.laps.copy()
            df_laps.insert(0,"year",year)
            df_laps.insert(0,"round_number",gp)
            all_laps_data.append(df_laps)
        
        except:
            print("No data available")
        # add the first row to end to make the lap complete
        


df_all_driver_data = pd.concat(all_laps_data)
# Out:
# core           INFO 	Loading data for Austrian Grand Prix - Race [v3.3.7]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for lap_count
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# core        WARNING 	Driver 77: Lap timing integrity check failed for 1 lap(s)
# core        WARNING 	Driver 16: Lap timing integrity check failed for 1 lap(s)
# core        WARNING 	Driver  4: Lap timing integrity check failed for 1 lap(s)
# core        WARNING 	Driver 44: Lap timing integrity check failed for 1 lap(s)
# core        WARNING 	Driver 55: Lap timing integrity check failed for 1 lap(s)
# ...

# %%
session.laps
# Out:
#       round_number  year                   Time Driver DriverNumber  \
# 0                3  2020 0 days 00:34:33.385000    HAM           44
# 1                3  2020 0 days 00:36:04.843000    HAM           44
# 2                3  2020 0 days 00:37:39.759000    HAM           44
# 3                3  2020 0 days 00:39:33.580000    HAM           44
# 4                3  2020 0 days 00:40:59.478000    HAM           44
# ...            ...   ...                    ...    ...          ...
# 1322             3  2020 0 days 00:49:58.145000    GAS           10
# 1323             3  2020 0 days 00:51:23.744000    GAS           10
# 1324             3  2020 0 days 00:52:50.350000    GAS           10
# 1325             3  2020 0 days 00:54:17.513000    GAS           10
# 1326             3  2020 0 days 00:55:47.988000    GAS           10
#
#                     LapTime  LapNumber  Stint             PitOutTime  \
# 0    0 days 00:01:35.670000        1.0    1.0                    NaT
# ...

# %%
df_all_driver_data.to_parquet("./static/data/all_laps.parquet")
