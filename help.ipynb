# %%
import pandas as pd

# %%
team_data = pd.read_csv('E2/static/data/df_agg_team.csv')

# %%
team_data[["Team Name", "3pt", "Free Throws"]]
# Out:
#                  Team Name   3pt  Free Throws
# 0                  retired  0.47         3.04
# 1            Atlanta Hawks  1.31         3.24
# 2           Boston Celtics  1.50         3.37
# 3            Brooklyn Nets  1.52         3.36
# 4        Charlotte Hornets  1.28         2.27
# 5            Chicago Bulls  1.25         1.97
# 6      Cleveland Cavaliers  0.94         2.83
# 7         Dallas Mavericks  1.45         2.41
# 8           Denver Nuggets  1.08         2.88
# 9          Detroit Pistons  1.35         2.88
# 10   Golden State Warriors  2.28         2.90
# 11         Houston Rockets  1.57         3.48
# 12          Indiana Pacers  1.41         2.27
# 13    Los Angeles Clippers  1.82         3.25
# 14      Los Angeles Lakers  1.14         3.49
# 15       Memphis Grizzlies  0.77         2.49
# 16              Miami Heat  1.19         2.83
# 17         Milwaukee Bucks  1.60         2.71
# 18  Minnesota Timberwolves  1.51         2.37
# ...
