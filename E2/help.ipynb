# %%
import pandas as pd
from sklearn import decomposition, preprocessing

# %%
team_data = pd.read_csv('static/data/df_agg_team.csv')

# %%
#team_data = team_data[["Team Name", "3pt", "Free Throws"]]

# %%
team_data["Team Name"].unique()
team_data.columns
# Out:
# Index(['Unnamed: 0', 'Team ID', 'Team Name', 'Number of Players', 'Height',
#        'Weight', 'Number of Birth Places', 'Total Games',
#        'Total Minutes Played', 'Field Goals', 'Field Goals Attempted',
#        'Field Goal %', '3pt', '3pt Attempted', '3pt %', '2pt', '2pt Attempted',
#        '2pt %', 'Free Throws', 'Free Throws Attempted', 'Free Throws %',
#        'Offensive Rebounds', 'Defensive Rebounds', 'Total Rebounds', 'Assists',
#        'Steals', 'Blocks', 'Turnovers', 'Personal Fouls', 'Points'],
#       dtype='object')

# %%
df_pca_team = team_data.set_index("Team Name", drop=True)
df_pca_team = df_pca_team.drop(index=["retired"]).select_dtypes("number")

scaler = preprocessing.StandardScaler()
scaled_team_data = scaler.fit_transform(df_pca_team)

pca = decomposition.PCA(n_components=2)
pca_team_data = pca.fit_transform(scaled_team_data)

df_pca_team_components = pd.DataFrame(pca_team_data, index=df_pca_team.index, columns=["x", "y"])

# %%
df_pca_team_components
# Out:
#                                x         y
# Team Name
# Atlanta Hawks           0.733516  2.809592
# Boston Celtics         -1.216483  1.898877
# Brooklyn Nets           1.563149  2.928311
# Charlotte Hornets       3.157685 -4.623661
# Chicago Bulls           1.142290 -1.883532
# Cleveland Cavaliers     7.646102  1.218193
# Dallas Mavericks       -0.264220 -2.558403
# Denver Nuggets          3.824268  1.088422
# Detroit Pistons        -1.823269  1.310701
# Golden State Warriors  -6.176193  2.047594
# Houston Rockets        -1.192185  0.134507
# Indiana Pacers         -0.901683 -2.019239
# Los Angeles Clippers   -2.802432  0.556754
# Los Angeles Lakers      2.398538  6.845972
# Memphis Grizzlies       6.347363 -0.341871
# Miami Heat              1.095224 -2.323595
# Milwaukee Bucks        -0.545913 -0.457688
# Minnesota Timberwolves -0.592413 -1.072218
# New Orleans Pelicans   -1.792679 -1.477116
# New York Knicks         1.156183 -3.017089
# Oklahoma City Thunder  -0.785053 -0.010848
# Orlando Magic          -1.665220 -3.349470
# Philadelphia 76ers      1.923557  1.317940
# Phoenix Suns           -1.356101 -1.102650
# Portland Trail Blazers -2.293956  4.235430
# Sacramento Kings       -2.088408 -3.224961
# San Antonio Spurs      -1.863653  2.746741
# Toronto Raptors         1.379614 -0.675127
# Utah Jazz              -1.138384 -1.100161
# Washington Wizards     -3.869246  0.098594

# %%
pd.melt(team_data, id_vars=["Team Name"])
# Out:
#              Team Name     variable  value
# 0              retired          3pt   0.47
# 1        Atlanta Hawks          3pt   1.31
# 2       Boston Celtics          3pt   1.50
# 3        Brooklyn Nets          3pt   1.52
# 4    Charlotte Hornets          3pt   1.28
# ..                 ...          ...    ...
# 57    Sacramento Kings  Free Throws   2.23
# 58   San Antonio Spurs  Free Throws   3.23
# 59     Toronto Raptors  Free Throws   2.85
# 60           Utah Jazz  Free Throws   2.70
# 61  Washington Wizards  Free Throws   2.87
#
# [62 rows x 3 columns]

# %%
team_data.style.background_gradient(cmap='Blues')
# Out:
# <style type="text/css">
# #T_3ae16_row0_col0, #T_3ae16_row0_col1, #T_3ae16_row0_col12, #T_3ae16_row0_col13, #T_3ae16_row0_col17, #T_3ae16_row1_col3, #T_3ae16_row1_col6, #T_3ae16_row1_col7, #T_3ae16_row1_col8, #T_3ae16_row2_col3, #T_3ae16_row2_col6, #T_3ae16_row2_col7, #T_3ae16_row2_col8, #T_3ae16_row3_col3, #T_3ae16_row3_col6, #T_3ae16_row3_col7, #T_3ae16_row3_col8, #T_3ae16_row4_col3, #T_3ae16_row4_col6, #T_3ae16_row4_col7, #T_3ae16_row4_col8, #T_3ae16_row4_col9, #T_3ae16_row4_col10, #T_3ae16_row4_col15, #T_3ae16_row4_col16, #T_3ae16_row4_col25, #T_3ae16_row4_col29, #T_3ae16_row5_col3, #T_3ae16_row5_col6, #T_3ae16_row5_col7, #T_3ae16_row5_col8, #T_3ae16_row5_col18, #T_3ae16_row5_col19, #T_3ae16_row6_col3, #T_3ae16_row6_col7, #T_3ae16_row6_col8, #T_3ae16_row6_col20, #T_3ae16_row6_col24, #T_3ae16_row7_col3, #T_3ae16_row7_col6, #T_3ae16_row7_col7, #T_3ae16_row7_col8, #T_3ae16_row7_col27, #T_3ae16_row8_col3, #T_3ae16_row8_col6, #T_3ae16_row8_col7, #T_3ae16_row8_col8, #T_3ae16_row9_col3, #T_3ae16_row9_col6, #T_3ae16_row9_col7, #T_3ae16_row9_col8, #T_3ae16_row9_col25, #T_3ae16_row10_col3, #T_3ae16_row10_col6, #T_3ae16_row10_col7, #T_3ae16_row10_col8, #T_3ae16_row10_col21, #T_3ae16_row11_col3, #T_3ae16_row11_col6, #T_3ae16_row11_col7, #T_3ae16_row12_col3, #T_3ae16_row12_col6, #T_3ae16_row12_col7, #T_3ae16_row12_col8, #T_3ae16_row13_col3, #T_3ae16_row13_col6, #T_3ae16_row13_col7, #T_3ae16_row13_col8, #T_3ae16_row14_col3, #T_3ae16_row14_col6, #T_3ae16_row15_col3, #T_3ae16_row15_col6, #T_3ae16_row15_col7, #T_3ae16_row15_col8, #T_3ae16_row15_col14, #T_3ae16_row16_col3, #T_3ae16_row16_col6, #T_3ae16_row16_col7, #T_3ae16_row16_col8, #T_3ae16_row16_col26, #T_3ae16_row17_col3, #T_3ae16_row17_col6, #T_3ae16_row18_col3, #T_3ae16_row18_col6, #T_3ae16_row18_col7, #T_3ae16_row18_col8, #T_3ae16_row19_col3, #T_3ae16_row19_col6, #T_3ae16_row19_col7, #T_3ae16_row19_col8, #T_3ae16_row19_col22, #T_3ae16_row19_col23, #T_3ae16_row20_col3, #T_3ae16_row20_col6, #T_3ae16_row20_col7, #T_3ae16_row20_col8, #T_3ae16_row21_col3, #T_3ae16_row21_col6, #T_3ae16_row21_col7, #T_3ae16_row21_col8, #T_3ae16_row22_col3,
{
#   background-color: #c2d9ee;
#   color: #000000;
# }
# #T_3ae16_row0_col24, #T_3ae16_row22_col29 {
#   background-color: #bad6eb;
#   color: #000000;
# }
# #T_3ae16_row0_col25, #T_3ae16_row26_col21, #T_3ae16_row30_col22 {
#   background-color: #ecf4fb;
#   color: #000000;
# }
# #T_3ae16_row0_col26, #T_3ae16_row4_col18, #T_3ae16_row7_col24, #T_3ae16_row11_col16, #T_3ae16_row12_col18, #T_3ae16_row12_col24, #T_3ae16_row12_col27, #T_3ae16_row20_col20, #T_3ae16_row26_col27 {
#   background-color: #d3e3f3;
#   color: #000000;
# }
# #T_3ae16_row0_col27, #T_3ae16_row2_col0, #T_3ae16_row2_col1 {
#   background-color: #eaf2fb;
#   color: #000000;
# }
# #T_3ae16_row0_col28, #T_3ae16_row25_col9 {
#   background-color: #08326e;
#   color: #f1f1f1;
# }
# #T_3ae16_row0_col29, #T_3ae16_row1_col25, #T_3ae16_row5_col29, #T_3ae16_row8_col12, #T_3ae16_row10_col11, #T_3ae16_row11_col9, #T_3ae16_row12_col26, #T_3ae16_row12_col28, #T_3ae16_row20_col11, #T_3ae16_row21_col28, #T_3ae16_row23_col19 {
#   background-color: #aacfe5;
#   color: #000000;
# }
# #T_3ae16_row1_col0, #T_3ae16_row1_col1, #T_3ae16_row24_col11 {
#   background-color: #f1f7fd;
#   color: #000000;
# }
# #T_3ae16_row1_col4 {
#   background-color: #0e59a2;
#   color: #f1f1f1;
# }
# #T_3ae16_row1_col5 {
#   background-color: #3484bf;
#   color: #f1f1f1;
# }
# #T_3ae16_row1_col9, #T_3ae16_row3_col29, #T_3ae16_row9_col10 {
#   background-color: #1c6bb0;
#   color: #f1f1f1;
# }
# #T_3ae16_row1_col10 {
#   background-color: #2c7cba;
#   color: #f1f1f1;
# }
# #T_3ae16_row1_col11, #T_3ae16_row5_col12, #T_3ae16_row13_col0, #T_3ae16_row13_col1, #T_3ae16_row16_col19, #T_3ae16_row19_col15, #T_3ae16_row21_col27, #T_3ae16_row24_col9 {
#   background-color: #87bddc;
#   color: #000000;
# }
# #T_3ae16_row1_col12, #T_3ae16_row8_col23, #T_3ae16_row17_col26, #T_3ae16_row18_col15, #T_3ae16_row20_col17 {
#   background-color: #7ab6d9;
#   color: #000000;
# }
# #T_3ae16_row1_col13, #T_3ae16_row4_col13, #T_3ae16_row10_col15, #T_3ae16_row12_col12 {
#   background-color: #65aad4;
#   color: #f1f1f1;
# }
# #T_3ae16_row1_col14, #T_3ae16_row7_col10, #T_3ae16_row11_col0, #T_3ae16_row11_col1, #T_3ae16_row20_col9 {
#   background-color: #a1cbe2;
#   color: #000000;
# }
# #T_3ae16_row1_col15, #T_3ae16_row3_col9, #T_3ae16_row8_col28, #T_3ae16_row11_col19, #T_3ae16_row23_col11 {
#   background-color: #2070b4;
#   color: #f1f1f1;
# }
# #T_3ae16_row1_col16, #T_3ae16_row11_col25 {
#   background-color: #2474b7;
#   color: #f1f1f1;
# }
# #T_3ae16_row1_col17, #T_3ae16_row3_col14, #T_3ae16_row5_col10 {
#   background-color: #84bcdb;
#   color: #000000;
# }
# #T_3ae16_row1_col18, #T_3ae16_row25_col19 {
#   background-color: #1967ad;
#   color: #f1f1f1;
# }
# #T_3ae16_row1_col19, #T_3ae16_row2_col19, #T_3ae16_row22_col13, #T_3ae16_row24_col13, #T_3ae16_row25_col12 {
#   background-color: #3c8cc3;
#   color: #f1f1f1;
# }
# #T_3ae16_row1_col20, #T_3ae16_row16_col4, #T_3ae16_row16_col20 {
#   background-

# %%
    df_cleaned_player_stats = pd.read_csv("./static/data/cleaned_df_player_stats.csv").drop(
        columns=["Unnamed: 0", "level_0", "index", "teams", "player_id", "player_url", "birth_place", "retired", "position", "height", "weight", "birth_date", "name", "full_name", "current_team_id"])
    df_cleaned_player_stats = df_cleaned_player_stats[df_cleaned_player_stats["team_name"]!="retired"]
    team_summary = df_cleaned_player_stats.groupby(["team_name", "season"]).sum().reset_index()
    team_summary['year'] = team_summary['season'].str.split('-').str[1]
    team_summary['year'] = team_summary['year'].astype(int)  
    team_summary['year'] = team_summary['year'].apply(lambda x: 1900 + x if x > 2024 % 100 else 2000 + x)
    team_summary.drop(columns=["season"], inplace=True)
    
    # TODO: delete this filter! only testing
    #team_summary = team_summary[team_summary["team_name"]=="Atlanta Hawks"]
    #team_summary = team_summary[["team_name", "year", "total_games"]]

# %%
team_summary["year"].min()
# Out:
# 1999
